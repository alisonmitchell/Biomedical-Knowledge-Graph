# %% [markdown]
# # GROBID (GeneRation Of BIbliographic Data)

# %% [markdown]
# ## 1. Introduction
#
# [GROBID](https://github.com/kermitt2/grobid) is a machine learning library for extracting, parsing and restructuring raw documents such as PDF into structured XML/TEI encoded documents with a particular focus on technical and scientific publications.
#
# Functionalities include full text extraction and structuring from PDF articles including a model for the overall document segmentation and models for the structuring of the text body (paragraph, section titles, reference and footnote callouts, figures, tables, data availability statements, etc.).
#
# We will use this to extract the full text from the arXiv PDFs for which we downloaded the metadata.

# %% [markdown]
# ## 2. Install/import libraries

# %%
import pandas as pd
import pickle
import re
import requests
import urllib
import time
import concurrent

from multiprocessing.pool import ThreadPool
from functools import lru_cache
from bs4 import BeautifulSoup, NavigableString, Tag
from itertools import chain
from collections import Counter

# %% [markdown]
# ## 3. Import arXiv PDF metadata
#
# Read in metadata collected via arXiv API with PDF URLs from export.arxiv.org subdomain.

# %%
article_results_arxiv_304 = pd.read_pickle('2023-01-06_arxiv_results_for_dl.pickle')
article_results_arxiv_304
# Out:
#          arxiv-id   published     revised  \
# 0    2109.06377v4  2021-09-14  2022-12-22
# 1    2212.09867v1  2022-12-19  2022-12-19
# 2    2212.09610v1  2022-12-19  2022-12-19
# 3    2212.00023v2  2022-11-30  2022-12-08
# 4    2212.03911v1  2022-12-07  2022-12-07
# ..            ...         ...         ...
# 299  2003.13665v1  2020-03-30  2020-03-30
# 300  2003.14258v1  2020-03-30  2020-03-30
# 301  2003.12454v1  2020-03-26  2020-03-26
# 302  2003.04524v1  2020-03-10  2020-03-10
# 303  2003.00751v1  2020-03-02  2020-03-02
#
#                                                  title journal  \
# 0    ASGARD: A Single-cell Guided pipeline to Aid R...    None
# 1    Detecting Contradictory COVID-19 Drug Efficacy...    None
# 2    Drying of Bio-colloidal Sessile Droplets: Adva...    None
# 3    Random Copolymer inverse design system orienti...    None
# 4    Analysis of Drug repurposing Knowledge graphs ...    None
# ..                                                 ...     ...
# 299  Genomics-guided molecular maps of coronavirus ...    None
# 300  Nanomechanical sonification of the 2019-nCoV c...    None
# 301  A Machine Learning alternative to placebo-cont...    None
# 302  Old Drugs for Newly Emerging Viral Disease, CO...    None
# 303  Regulation of interferon production as a poten...    None
#
#                                                authors   doi  \
# 0    Bing He, Yao Xiao, Haodong Liang, Qianhui Huan...  None
# 1    Daniel N. Sosa, Malavika Suresh, Christopher P...  None
# 2           Anusuya Pal, Amalesh Gope, Anupam Sengupta  None
# 3                                 Tianyu Wu, Yang Tang  None
# 4                                  Ajay Kumar Gogineni  None
# ..                                                 ...   ...
# 299                                    Gennadi Glinsky  None
# 300                                  Markus J. Buehler  None
# 301   Ezequiel Alvarez, Federico Lamagna, Manuel Szewc  None
# 302                                Mohammad Reza Dayer  None
# 303             Xiaobing Deng, Xiaoyu Yu, Jianfeng Pei  None
#
#                                       pdf_url
# 0    http://export.arxiv.org/pdf/2109.06377v4
# 1    http://export.arxiv.org/pdf/2212.09867v1
# 2    http://export.arxiv.org/pdf/2212.09610v1
# 3    http://export.arxiv.org/pdf/2212.00023v2
# 4    http://export.arxiv.org/pdf/2212.03911v1
# ..                                        ...
# 299  http://export.arxiv.org/pdf/2003.13665v1
# 300  http://export.arxiv.org/pdf/2003.14258v1
# 301  http://export.arxiv.org/pdf/2003.12454v1
# 302  http://export.arxiv.org/pdf/2003.04524v1
# 303  http://export.arxiv.org/pdf/2003.00751v1
#
# [304 rows x 8 columns]

# %% [markdown]
# ## 4. Download full text as XML
#
# Create a function to download parsed XML for each PDF using a Python wrapper for the public GROBID demo server available for testing purposes. Please note according to the [GROBID repo](https://github.com/kermitt2/grobid/) quota and query limitations apply to the demo server and for any serious works you will need to deploy and use your own GROBID server. If a document exceeds the max token limit you will get an exception e.g. Exception('[TOO_MANY_TOKENS] The document has 1374455 tokens, but the limit is 1000000').
#
# The code below used the previous demo server hosted at [https://cloud.science-miner.com/grobid](https://cloud.science-miner.com/grobid) which has since been updated and redirects to a new demo server with a combination of Deep Learning models and CRF models hosted on Hugging Face Spaces at [https://kermitt2-grobid.hf.space/](https://kermitt2-grobid.hf.space/) or [ https://huggingface.co/spaces/kermitt2/grobid](https://huggingface.co/spaces/kermitt2/grobid).
#
# A faster demo with CRF only is available at https://kermitt2-grobid-crf.hf.space/ or https://huggingface.co/spaces/kermitt2/grobid-crf.
#
# Updating the GROBID URL in the function to [https://kermitt2-grobid.hf.space/api/processFulltextDocument](https://kermitt2-grobid.hf.space/api/processFulltextDocument) will be necessary.

# %%
# Adapted from https://github.com/titipata/scipdf_parser/blob/master/scipdf/pdf/parse_pdf.py

def parse_pdf(pdf_url: str):
    """
    Parse PDF to XML using GROBID tool

    :param pdf_url: str, URL to article PDF

    :return: XML of parsed article
    """
    # GROBID URL for the cloud service to parse full text of the article
    url = "https://cloud.science-miner.com/grobid/api/processFulltextDocument"

    if isinstance(pdf_url, str):
            page = urllib.request.urlopen(pdf_url).read()
            resp = requests.post(url, files={"input": page})
            if resp.status_code != 200:
              raise Exception(resp.text)
            parsed_article = resp.text
            time.sleep(3)
    else:
        raise TypeError("Need to supply a url")


    return parsed_article

# %% [markdown]
# Multithreading is used here since the code is I/O-bound rather than CPU-bound. Executing multiple threads concurrently speeds up the process as opposed to just iterating through the pdf_url list using a for loop calling the parse_pdf() function sequentially for each URL.

# %%
with concurrent.futures.ThreadPoolExecutor(4) as executor:
     futures = [executor.submit(parse_pdf, pdf_url) for pdf_url in article_results_arxiv_304.pdf_url]
     concurrent.futures.wait(futures)

# %% [markdown]
# Create a dictionary of futures which are proxies for results that do not yet exist but will in the future.

# %%
futures_map = dict(zip(article_results_arxiv_304.pdf_url, futures))
futures_map
# Out:
# {'http://export.arxiv.org/pdf/2109.06377v4': <Future at 0x7f9fc2e3d490 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2212.09867v1': <Future at 0x7f9fc6be80d0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2212.09610v1': <Future at 0x7f9fc2e3db50 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2212.00023v2': <Future at 0x7f9fc2e3de20 state=finished raised Exception>,
#  'http://export.arxiv.org/pdf/2212.03911v1': <Future at 0x7f9fc6174670 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2212.01575v1': <Future at 0x7f9fc616dac0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2103.02009v2': <Future at 0x7f9fc616d910 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2204.08697v2': <Future at 0x7f9fc616d8e0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2207.09551v2': <Future at 0x7f9fc616da00 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2107.02905v2': <Future at 0x7f9fc616d730 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2211.00201v2': <Future at 0x7f9fc2e380d0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2011.11576v3': <Future at 0x7f9fc2e381c0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2008.00127v2': <Future at 0x7f9fc2e382b0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2205.11966v2': <Future at 0x7f9fc2e383a0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2210.04774v1': <Future at 0x7f9fc2e38490 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2209.04431v2': <Future at 0x7f9fc2e38580 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2206.07375v2': <Future at 0x7f9fc2e38670 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2210.01882v1': <Future at 0x7f9fc2e38760 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2209.13773v1': <Future at 0x7f9fc2e38850 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2110.15803v3': <Future at 0x7f9fc2e38940 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2209.11508v1': <Future at 0x7f9fc2e38a30 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2209.09810v1': <Future at 0x7f9fc2e38b20 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2209.05069v1': <Future at 0x7f9fc2e38c10 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2003.00728v3': <Future at 0x7f9fc2e38d00 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2209.00114v1': <Future at 0x7f9fc6174a00 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2208.06362v3': <Future at 0x7f9fc617a1f0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2208.06355v1': <Future at 0x7f9fc617aee0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2208.05019v1': <Future at 0x7f9fc2e40760 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2206.01047v2': <Future at 0x7f9fc2e40820 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2206.14358v1': <Future at 0x7f9fc2e40970 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2206.13634v1': <Future at 0x7f9fc2e40430 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2206.06111v1': <Future at 0x7f9fc2e404f0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2110.11584v2': <Future at 0x7f9fc2e40670 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2206.02970v1': <Future at 0x7f9fc2e40160 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2204.09781v3': <Future at 0x7f9fc2e40220 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2205.14781v1': <Future at 0x7f9fc2e40340 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2205.05618v1': <Future at 0x7f9fc2e40280 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2012.12263v3': <Future at 0x7f9fc2e40250 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2110.07531v2': <Future at 0x7f9fc2e69ee0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2204.09471v1': <Future at 0x7f9fc2e69190 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2204.04017v1': <Future at 0x7f9fc2e69c10 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2201.00287v3': <Future at 0x7f9fc2e69be0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2102.05470v5': <Future at 0x7f9fc2e693d0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2203.10338v1': <Future at 0x7f9fc2e69f70 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.10177v7': <Future at 0x7f9fc2e69e20 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2202.05145v1': <Future at 0x7f9fc2e695e0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2202.01962v1': <Future at 0x7f9fc2e69790 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2009.10931v3': <Future at 0x7f9fc2e69a90 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2202.00143v1': <Future at 0x7f9fc2e69b20 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2201.12237v1': <Future at 0x7f9fc2e69a00 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2201.08176v1': <Future at 0x7f9fc2e694f0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2108.13751v3': <Future at 0x7f9fc2e696a0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2201.00237v1': <Future at 0x7f9fc2e69700 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2112.02560v2': <Future at 0x7f9fc3aaed90 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2112.01318v1': <Future at 0x7f9fc3aae250 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2109.06711v2': <Future at 0x7f9fc3aaea00 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2111.14480v1': <Future at 0x7f9fc3aaeaf0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2111.14283v1': <Future at 0x7f9fc3aae520 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2111.11955v1': <Future at 0x7f9fc3aa9d90 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2110.13522v2': <Future at 0x7f9fc3aa9400 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2110.13971v1': <Future at 0x7f9fc3aa9e50 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2110.12450v1': <Future at 0x7f9fc3a20880 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2110.09606v1': <Future at 0x7f9fc3a20250 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2110.06397v1': <Future at 0x7f9fc3a204c0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.07567v2': <Future at 0x7f9fc3a20d30 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2109.13739v2': <Future at 0x7f9fc3a20400 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2109.03565v2': <Future at 0x7f9fc3a208e0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2106.13375v2': <Future at 0x7f9fc3a20430 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2103.02723v3': <Future at 0x7f9fc3a20640 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2109.00100v4': <Future at 0x7f9fc3a20b50 state=finished raised Exception>,
#  'http://export.arxiv.org/pdf/2109.00435v3': <Future at 0x7f9fc3a206a0 state=finished raised Exception>,
#  'http://export.arxiv.org/pdf/2010.16413v3': <Future at 0x7f9fc3a20f40 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2103.02843v2': <Future at 0x7f9fc3a20eb0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2108.13764v1': <Future at 0x7f9fc3a20fa0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2108.12150v1': <Future at 0x7f9fc615fe20 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2107.05347v2': <Future at 0x7f9fc615f880 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2108.09739v1': <Future at 0x7f9fc61b9c10 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2108.07046v2': <Future at 0x7f9fc2e38e20 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2108.06473v1': <Future at 0x7f9fc2e38f10 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2104.09394v2': <Future at 0x7f9fc2e50040 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2104.12556v3': <Future at 0x7f9fc2e50130 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2108.00664v1': <Future at 0x7f9fc2e50220 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2107.12799v1': <Future at 0x7f9fc2e50310 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2107.12463v1': <Future at 0x7f9fc2e50400 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2107.09217v1': <Future at 0x7f9fc2e504f0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2107.09602v1': <Future at 0x7f9fc2e505e0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2012.01981v3': <Future at 0x7f9fc2e506d0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2106.14631v1': <Future at 0x7f9fc2e507c0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2106.12297v1': <Future at 0x7f9fc2e508b0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2102.09507v4': <Future at 0x7f9fc2e509a0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2106.06911v1': <Future at 0x7f9fc2e50a90 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2106.05440v1': <Future at 0x7f9fc2e50b80 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2104.01533v2': <Future at 0x7f9fc2e50c70 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2104.14005v3': <Future at 0x7f9fc2e50d60 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2106.00356v1': <Future at 0x7f9fc2e50e50 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2105.14433v1': <Future at 0x7f9fc2e50f40 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2105.14333v1': <Future at 0x7f9fc2e57070 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2105.12267v1': <Future at 0x7f9fc2e57160 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2105.11410v1': <Future at 0x7f9fc2e57250 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2010.04700v3': <Future at 0x7f9fc2e57340 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2008.11308v2': <Future at 0x7f9fc2e57430 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2007.00576v6': <Future at 0x7f9fc2e57520 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2105.05220v1': <Future at 0x7f9fc2e57610 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2105.10489v1': <Future at 0x7f9fc2e57700 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2006.03146v3': <Future at 0x7f9fc2e577f0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2104.13224v1': <Future at 0x7f9fc2e578e0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2104.12003v1': <Future at 0x7f9fc2e579d0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2104.11674v1': <Future at 0x7f9fc2e57ac0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2103.15561v2': <Future at 0x7f9fc2e57bb0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2104.08867v1': <Future at 0x7f9fc2e57ca0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2104.07367v1': <Future at 0x7f9fc2e57d90 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2104.05321v1': <Future at 0x7f9fc2e57e80 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2104.05188v1': <Future at 0x7f9fc2e57f70 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2104.01113v2': <Future at 0x7f9fc2e5e0a0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2103.16192v1': <Future at 0x7f9fc2e5e190 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2008.04172v4': <Future at 0x7f9fc2e5e280 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2103.14102v1': <Future at 0x7f9fc2e5e370 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2103.13844v1': <Future at 0x7f9fc2e5e460 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2103.13297v1': <Future at 0x7f9fc2e5e550 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2006.03354v2': <Future at 0x7f9fc2e5e640 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2103.06578v1': <Future at 0x7f9fc2e5e730 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2007.02202v2': <Future at 0x7f9fc2e5e820 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2010.06357v2': <Future at 0x7f9fc2e5e910 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2007.10445v2': <Future at 0x7f9fc2e5ea00 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2103.01896v1': <Future at 0x7f9fc2e5eaf0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2102.13103v1': <Future at 0x7f9fc2e5ebe0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2102.08628v1': <Future at 0x7f9fc2e5ecd0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2102.07610v1': <Future at 0x7f9fc2e5edc0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2102.07022v1': <Future at 0x7f9fc2e5eeb0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2102.04977v1': <Future at 0x7f9fc2e5efa0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2010.09600v2': <Future at 0x7f9fc0fb20d0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2102.02250v1': <Future at 0x7f9fc0fb21c0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2102.00971v1': <Future at 0x7f9fc0fb22b0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2102.00197v1': <Future at 0x7f9fc0fb23a0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2101.12547v1': <Future at 0x7f9fc0fb2490 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2101.11990v1': <Future at 0x7f9fc0fb2580 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2101.07824v1': <Future at 0x7f9fc0fb2670 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2101.04617v1': <Future at 0x7f9fc0fb2760 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2003.11336v3': <Future at 0x7f9fc0fb2850 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2101.11710v1': <Future at 0x7f9fc0fb2940 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2101.03133v1': <Future at 0x7f9fc0fb2a30 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2101.01884v1': <Future at 0x7f9fc0fb2b20 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.13493v4': <Future at 0x7f9fc0fb2c10 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2012.13605v1': <Future at 0x7f9fc0fb2d00 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2012.06139v1': <Future at 0x7f9fc0fb2df0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2012.04682v2': <Future at 0x7f9fc0fb2ee0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.07856v2': <Future at 0x7f9fc0fb2fd0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2012.02151v1': <Future at 0x7f9fc0fb8100 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2012.01953v1': <Future at 0x7f9fc0fb81f0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2012.00627v1': <Future at 0x7f9fc0fb82e0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2011.14241v1': <Future at 0x7f9fc0fb83d0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2011.04651v2': <Future at 0x7f9fc0fb84c0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2011.12350v1': <Future at 0x7f9fc0fb85b0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.01453v4': <Future at 0x7f9fc0fb86a0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2012.05836v1': <Future at 0x7f9fc0fb8790 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2011.08902v1': <Future at 0x7f9fc0fb8880 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2011.00336v2': <Future at 0x7f9fc0fb8970 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2007.15681v2': <Future at 0x7f9fc0fb8a60 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2011.03983v1': <Future at 0x7f9fc0fb8b50 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2012.00653v1': <Future at 0x7f9fc0fb8c40 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2012.00652v1': <Future at 0x7f9fc0fb8d30 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2007.15209v3': <Future at 0x7f9fc0fb8e20 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2011.01251v1': <Future at 0x7f9fc0fb8f10 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2009.04438v2': <Future at 0x7f9fc0fbf040 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2010.16325v1': <Future at 0x7f9fc0fbf130 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2010.07883v2': <Future at 0x7f9fc0fbf220 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2010.11367v2': <Future at 0x7f9fc0fbf310 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2010.12332v1': <Future at 0x7f9fc0fbf400 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2010.10517v1': <Future at 0x7f9fc0fbf4f0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2010.08855v1': <Future at 0x7f9fc0fbf5e0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2010.07586v1': <Future at 0x7f9fc0fbf6d0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2010.06574v1': <Future at 0x7f9fc0fbf7c0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2010.02417v2': <Future at 0x7f9fc0fbf8b0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2007.10276v2': <Future at 0x7f9fc0fbf9a0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2010.04420v1': <Future at 0x7f9fc0fbfa90 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2010.04115v1': <Future at 0x7f9fc0fbfb80 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2007.09186v3': <Future at 0x7f9fc0fbfc70 state=finished raised Exception>,
#  'http://export.arxiv.org/pdf/2005.02261v2': <Future at 0x7f9fc0fbfd60 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2010.01916v1': <Future at 0x7f9fc0fbfe50 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2009.12817v1': <Future at 0x7f9fc0fbff40 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2009.11568v1': <Future at 0x7f9fc0fc7070 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2009.10333v1': <Future at 0x7f9fc0fc7160 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2009.10049v1': <Future at 0x7f9fc0fc7250 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.12668v3': <Future at 0x7f9fc0fc7340 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2007.07736v4': <Future at 0x7f9fc0fc7430 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2008.03397v2': <Future at 0x7f9fc0fc7520 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2009.13602v1': <Future at 0x7f9fc0fc7610 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2009.03068v1': <Future at 0x7f9fc0fc7700 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2009.01094v1': <Future at 0x7f9fc0fc77f0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2009.00744v1': <Future at 0x7f9fc0fc78e0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2009.08861v1': <Future at 0x7f9fc0fc79d0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2008.12353v1': <Future at 0x7f9fc0fc7ac0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2008.09649v1': <Future at 0x7f9fc0fc7bb0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2008.07488v2': <Future at 0x7f9fc0fc7ca0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2008.07880v1': <Future at 0x7f9fc0fc7d90 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.00979v3': <Future at 0x7f9fc0fc7e80 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2008.06974v1': <Future at 0x7f9fc0fc7f70 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2008.06755v1': <Future at 0x7f9fc0fcd0a0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2006.14492v4': <Future at 0x7f9fc0fcd190 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2008.05377v1': <Future at 0x7f9fc0fcd280 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.10233v5': <Future at 0x7f9fc0fcd370 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.07229v2': <Future at 0x7f9fc0fcd460 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2008.03283v1': <Future at 0x7f9fc0fcd550 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2003.00163v2': <Future at 0x7f9fc2e69940 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2007.00621v2': <Future at 0x7f9fc0fcd5e0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2008.07350v1': <Future at 0x7f9fc0fcd6d0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2008.04045v1': <Future at 0x7f9fc0fcd7c0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2006.02772v2': <Future at 0x7f9fc0fcd8b0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2007.16177v1': <Future at 0x7f9fc0fcd9a0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2007.01902v2': <Future at 0x7f9fc0fcda90 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2007.15835v1': <Future at 0x7f9fc0fcdb80 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2007.14965v1': <Future at 0x7f9fc0fcdc70 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.08095v3': <Future at 0x7f9fc0fcdd60 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2007.14375v1': <Future at 0x7f9fc0fcde50 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2007.14805v1': <Future at 0x7f9fc0fcdf40 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2007.12731v1': <Future at 0x7f9fc0fd4070 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2007.12242v1': <Future at 0x7f9fc0fd4160 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.07955v2': <Future at 0x7f9fc0fd4250 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2007.10261v1': <Future at 0x7f9fc0fd4340 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2006.06435v3': <Future at 0x7f9fc0fd4430 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.10706v4': <Future at 0x7f9fc0fd4520 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.00662v5': <Future at 0x7f9fc0fd4610 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2007.04809v1': <Future at 0x7f9fc0fd4700 state=finished returned str>,
#  'http://export.arxiv.org/pdf/1808.04773v2': <Future at 0x7f9fc0fd47f0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2007.03678v1': <Future at 0x7f9fc0fd48e0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.13285v3': <Future at 0x7f9fc0fd49d0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2007.02557v1': <Future at 0x7f9fc0fd4ac0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2007.02338v1': <Future at 0x7f9fc0fd4bb0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2007.10287v1': <Future at 0x7f9fc0fd4ca0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2007.01800v1': <Future at 0x7f9fc0fd4d90 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2003.13997v4': <Future at 0x7f9fc0fd4e80 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2006.01284v3': <Future at 0x7f9fc0fd4f70 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2006.01226v2': <Future at 0x7f9fc0fdc0a0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2006.02936v2': <Future at 0x7f9fc0fdc190 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2006.03110v3': <Future at 0x7f9fc0fdc280 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2006.14790v1': <Future at 0x7f9fc0fdc370 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2006.14707v1': <Future at 0x7f9fc0fdc460 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.01215v2': <Future at 0x7f9fc0fdc550 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.02631v4': <Future at 0x7f9fc0fdc640 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2006.16926v1': <Future at 0x7f9fc0fdc730 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2006.10584v1': <Future at 0x7f9fc0fdc820 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2006.09125v2': <Future at 0x7f9fc0fdc910 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2006.06452v1': <Future at 0x7f9fc0fdca00 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.12124v2': <Future at 0x7f9fc0fdcaf0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2006.06523v1': <Future at 0x7f9fc0fdcbe0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2006.05502v1': <Future at 0x7f9fc0fdccd0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.11088v2': <Future at 0x7f9fc0fdcdc0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2006.00652v1': <Future at 0x7f9fc0fdceb0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2006.00343v1': <Future at 0x7f9fc0fdcfa0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2006.02343v1': <Future at 0x7f9fc0fe20d0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2006.02431v1': <Future at 0x7f9fc0fe21c0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.13653v1': <Future at 0x7f9fc0fe22b0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.06891v2': <Future at 0x7f9fc0fe23a0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.11260v2': <Future at 0x7f9fc0fe2490 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.11767v1': <Future at 0x7f9fc0fe2580 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.11458v1': <Future at 0x7f9fc0fe2670 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.11254v1': <Future at 0x7f9fc0fe2760 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.05625v2': <Future at 0x7f9fc0fe2850 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.10797v1': <Future at 0x7f9fc0fe2940 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.10831v1': <Future at 0x7f9fc0fe2a30 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.10028v1': <Future at 0x7f9fc0fe2b20 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.09805v1': <Future at 0x7f9fc0fe2c10 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.12137v1': <Future at 0x7f9fc0fe2d00 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.02666v2': <Future at 0x7f9fc0fe2df0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.08224v1': <Future at 0x7f9fc0fe2ee0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.06380v2': <Future at 0x7f9fc0fe2fd0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.05954v1': <Future at 0x7f9fc0fe8100 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.07121v1': <Future at 0x7f9fc0fe81f0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.03004v1': <Future at 0x7f9fc0fe82e0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.02289v1': <Future at 0x7f9fc0fe83d0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.02188v1': <Future at 0x7f9fc0fe84c0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.04108v1': <Future at 0x7f9fc0fe85b0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.07697v2': <Future at 0x7f9fc0fe86a0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.01042v1': <Future at 0x7f9fc0fe8790 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2003.14333v2': <Future at 0x7f9fc0fe8880 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2005.00485v1': <Future at 0x7f9fc0fe8970 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.14114v1': <Future at 0x7f9fc0fe8a60 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.13457v1': <Future at 0x7f9fc0fe8b50 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.12420v1': <Future at 0x7f9fc0fe8c40 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.12055v1': <Future at 0x7f9fc0fe8d30 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.11695v1': <Future at 0x7f9fc0fe8e20 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.10878v1': <Future at 0x7f9fc0fe8f10 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.10641v1': <Future at 0x7f9fc0f6f040 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.08920v1': <Future at 0x7f9fc0f6f130 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.08557v1': <Future at 0x7f9fc0f6f220 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.08491v1': <Future at 0x7f9fc0f6f310 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.00217v2': <Future at 0x7f9fc0f6f400 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.07750v1': <Future at 0x7f9fc0f6f4f0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2003.10642v2': <Future at 0x7f9fc0f6f5e0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.07086v1': <Future at 0x7f9fc0f6f6d0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.06447v1': <Future at 0x7f9fc0f6f7c0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.05684v1': <Future at 0x7f9fc0f6f8b0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.02136v3': <Future at 0x7f9fc0f6f9a0 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.04874v1': <Future at 0x7f9fc0f6fa90 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.03766v1': <Future at 0x7f9fc0f6fb80 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.02085v1': <Future at 0x7f9fc0f6fc70 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2003.13670v4': <Future at 0x7f9fc0f6fd60 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.01634v1': <Future at 0x7f9fc0f6fe50 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2004.00746v1': <Future at 0x7f9fc0f6ff40 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2003.13665v1': <Future at 0x7f9fc0f76070 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2003.14258v1': <Future at 0x7f9fc0f76160 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2003.12454v1': <Future at 0x7f9fc0f76250 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2003.04524v1': <Future at 0x7f9fc0f76340 state=finished returned str>,
#  'http://export.arxiv.org/pdf/2003.00751v1': <Future at 0x7f9fc0f76430 state=finished returned str>}

# %%
len(futures_map)
# Out:
# 304

# %% [markdown]
# Create dictionary of exceptions with PDF URL as key and exception error message as value.

# %%
exceptions = {url: f.exception() for url, f in futures_map.items() if f.exception() is not None}
exceptions
# Out:
# {'http://export.arxiv.org/pdf/2212.00023v2': Exception('[BAD_INPUT_DATA] PDF to XML conversion failed with error code: 1'),
#  'http://export.arxiv.org/pdf/2109.00100v4': Exception('[BAD_INPUT_DATA] PDF to XML conversion failed with error code: 1'),
#  'http://export.arxiv.org/pdf/2109.00435v3': Exception('[BAD_INPUT_DATA] PDF to XML conversion failed with error code: 1'),
#  'http://export.arxiv.org/pdf/2007.09186v3': Exception('[GENERAL] An exception occurred while running Grobid.')}

# %% [markdown]
# Four exceptions were found. The three with Exception(' [BAD_INPUT_DATA] PDF to XML conversion failed with error code: 1') are caused by the PDFs being unavailable so no XML would have been extracted. The one with Exception('[GENERAL] An exception occurred while running Grobid.') is a legitimate PDF but something went wrong during processing.

# %%
results = {url: f.result()[:100] for url, f in futures_map.items() if f.exception() is None}
results
# Out:
# {'http://export.arxiv.org/pdf/2109.06377v4': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2212.09867v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2212.09610v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2212.03911v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2212.01575v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2103.02009v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2204.08697v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2207.09551v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2107.02905v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2211.00201v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2011.11576v3': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2008.00127v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2205.11966v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2210.04774v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2209.04431v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2206.07375v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2210.01882v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2209.13773v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2110.15803v3': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2209.11508v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2209.09810v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2209.05069v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2003.00728v3': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2209.00114v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2208.06362v3': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2208.06355v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2208.05019v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2206.01047v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2206.14358v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2206.13634v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2206.06111v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2110.11584v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2206.02970v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2204.09781v3': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2205.14781v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2205.05618v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2012.12263v3': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2110.07531v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2204.09471v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2204.04017v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2201.00287v3': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2102.05470v5': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2203.10338v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.10177v7': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2202.05145v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2202.01962v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2009.10931v3': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2202.00143v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2201.12237v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2201.08176v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2108.13751v3': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2201.00237v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2112.02560v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2112.01318v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2109.06711v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2111.14480v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2111.14283v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2111.11955v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2110.13522v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2110.13971v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2110.12450v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2110.09606v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2110.06397v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.07567v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2109.13739v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2109.03565v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2106.13375v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2103.02723v3': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2010.16413v3': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2103.02843v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2108.13764v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2108.12150v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2107.05347v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2108.09739v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2108.07046v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2108.06473v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2104.09394v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2104.12556v3': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2108.00664v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2107.12799v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2107.12463v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2107.09217v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2107.09602v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2012.01981v3': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2106.14631v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2106.12297v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2102.09507v4': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2106.06911v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2106.05440v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2104.01533v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2104.14005v3': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2106.00356v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2105.14433v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2105.14333v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2105.12267v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2105.11410v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2010.04700v3': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2008.11308v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2007.00576v6': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2105.05220v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2105.10489v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2006.03146v3': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2104.13224v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2104.12003v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2104.11674v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2103.15561v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2104.08867v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2104.07367v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2104.05321v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2104.05188v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2104.01113v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2103.16192v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2008.04172v4': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2103.14102v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2103.13844v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2103.13297v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2006.03354v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2103.06578v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2007.02202v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2010.06357v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2007.10445v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2103.01896v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2102.13103v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2102.08628v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2102.07610v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2102.07022v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2102.04977v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2010.09600v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2102.02250v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2102.00971v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2102.00197v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2101.12547v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2101.11990v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2101.07824v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2101.04617v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2003.11336v3': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2101.11710v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2101.03133v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2101.01884v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.13493v4': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2012.13605v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2012.06139v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2012.04682v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.07856v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2012.02151v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2012.01953v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2012.00627v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2011.14241v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2011.04651v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2011.12350v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.01453v4': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2012.05836v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2011.08902v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2011.00336v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2007.15681v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2011.03983v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2012.00653v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2012.00652v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2007.15209v3': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2011.01251v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2009.04438v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2010.16325v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2010.07883v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2010.11367v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2010.12332v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2010.10517v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2010.08855v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2010.07586v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2010.06574v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2010.02417v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2007.10276v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2010.04420v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2010.04115v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.02261v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2010.01916v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2009.12817v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2009.11568v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2009.10333v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2009.10049v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.12668v3': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2007.07736v4': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2008.03397v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2009.13602v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2009.03068v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2009.01094v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2009.00744v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2009.08861v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2008.12353v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2008.09649v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2008.07488v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2008.07880v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.00979v3': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2008.06974v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2008.06755v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2006.14492v4': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2008.05377v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.10233v5': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.07229v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2008.03283v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2003.00163v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2007.00621v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2008.07350v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2008.04045v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2006.02772v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2007.16177v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2007.01902v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2007.15835v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2007.14965v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.08095v3': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2007.14375v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2007.14805v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2007.12731v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2007.12242v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.07955v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2007.10261v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2006.06435v3': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.10706v4': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.00662v5': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2007.04809v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/1808.04773v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2007.03678v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.13285v3': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2007.02557v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2007.02338v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2007.10287v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2007.01800v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2003.13997v4': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2006.01284v3': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2006.01226v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2006.02936v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2006.03110v3': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2006.14790v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2006.14707v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.01215v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.02631v4': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2006.16926v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2006.10584v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2006.09125v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2006.06452v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.12124v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2006.06523v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2006.05502v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.11088v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2006.00652v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2006.00343v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2006.02343v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2006.02431v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.13653v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.06891v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.11260v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.11767v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.11458v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.11254v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.05625v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.10797v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.10831v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.10028v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.09805v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.12137v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.02666v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.08224v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.06380v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.05954v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.07121v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.03004v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.02289v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.02188v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.04108v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.07697v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.01042v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2003.14333v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2005.00485v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.14114v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.13457v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.12420v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.12055v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.11695v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.10878v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.10641v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.08920v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.08557v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.08491v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.00217v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.07750v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2003.10642v2': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.07086v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.06447v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.05684v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.02136v3': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.04874v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.03766v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.02085v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2003.13670v4': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.01634v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2004.00746v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2003.13665v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2003.14258v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2003.12454v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2003.04524v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"',
#  'http://export.arxiv.org/pdf/2003.00751v1': '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0"'}

# %% [markdown]
# Amend the parse_pdf function with error handling for specific exceptions and run again to download the full text.
#
# We will use the @lru_cache decorator from Python's functools module which helps in reducing the execution time of the function for the same inputs by using the memoization technique.

# %%
@lru_cache(maxsize=None)
def parse_pdf(pdf_url: str):
    """
    Parse PDF to XML using GROBID tool

    :param pdf_url: str, URL to article PDF

    :return: XML of parsed article
    """
    # GROBID URL for the cloud service to parse full text of the article
    url = "https://cloud.science-miner.com/grobid/api/processFulltextDocument"

    if isinstance(pdf_url, str):
            page = urllib.request.urlopen(pdf_url).read()
            resp = requests.post(url, files={"input": page})
            if resp.status_code != 200:
                if resp.status_code >= 500:
                  retry = 1
                else:
                  return "500"
                if resp.text in ['[BAD_INPUT_DATA] PDF to XML conversion failed with error code: 1']:
                    return "1"
                if resp.text in ['{\n  "message":"An invalid response was received from the upstream server"\n}',
                                '[GENERAL] An exception occurred while running Grobid.']:
                    return "0"
                else:
                    raise Exception(resp.text)
            parsed_article = resp.text
            time.sleep(3)
    else:
        raise TypeError("Need to supply a url")


    return parsed_article

# %%
with ThreadPool(4) as pool:
  dl_pdf_xml = pool.map(parse_pdf, article_results_arxiv_304.pdf_url)

# %%
with open('2023-01-06_grobid_xml_str_v2.pickle', "wb") as f:
    pickle.dump(dl_pdf_xml, f)

# %%
len(dl_pdf_xml)
# Out:
# 304

# %% [markdown]
# Check XML output for first article which was extracted successfully.

# %%
dl_pdf_xml[0]
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0" \nxmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" \nxsi:schemaLocation="http://www.tei-c.org/ns/1.0 https://raw.githubusercontent.com/kermitt2/grobid/master/grobid-home/schemas/xsd/Grobid.xsd"\n xmlns:xlink="http://www.w3.org/1999/xlink">\n\t<teiHeader xml:lang="en">\n\t\t<fileDesc>\n\t\t\t<titleStmt>\n\t\t\t\t<title level="a" type="main">ASGARD: A Single-cell Guided Pipeline to Aid Repurposing of Drugs</title>\n\t\t\t</titleStmt>\n\t\t\t<publicationStmt>\n\t\t\t\t<publisher/>\n\t\t\t\t<availability status="unknown"><licence/></availability>\n\t\t\t</publicationStmt>\n\t\t\t<sourceDesc>\n\t\t\t\t<biblStruct>\n\t\t\t\t\t<analytic>\n\t\t\t\t\t\t<author>\n\t\t\t\t\t\t\t<persName><forename type="first">Bing</forename><surname>He</surname></persName>\n\t\t\t\t\t\t\t<affiliation key="aff0">\n\t\t\t\t\t\t\t\t<orgName type="department" key="dep1">Department of Computational Medicine and Bioinformatics</orgName>\n\t\t\t\t\t\t\t\t<orgName type="department" key="dep2">Medical School</orgName>\n\t\t\t\t\t\t\t\t<orgName type="institution">University of Michigan</orgName>\n\t\t\t\t\t\t\t\t<address>\n\t\t\t\t\t\t\t\t\t<settlement>Ann Arbor</settlement>\n\t\t\t\t\t\t\t\t\t<region>MI</region>\n\t\t\t\t\t\t\t\t\t<country key="US">USA</country>\n\t\t\t\t\t\t\t\t</address>\n\t\t\t\t\t\t\t</affiliation>\n\t\t\t\t\t\t</author>\n\t\t\t\t\t\t<author>\n\t\t\t\t\t\t\t<persName><forename type="first">Yao</forename><surname>Xiao</surname></persName>\n\t\t\t\t\t\t\t<affiliation key="aff0">\n\t\t\t\t\t\t\t\t<orgName type="department" key="dep1">Department of Computational Medicine and Bioinformatics</orgName>\n\t\t\t\t\t\t\t\t<orgName type="department" key="dep2">Medical School</orgName>\n\t\t\t\t\t\t\t\t<orgName type="institution">University of Michigan</orgName>\n\t\t\t\t\t\t\t\t<address>\n\t\t\t\t\t\t\t\t\t<settlement>Ann Arbor</settlement>\n\t\t\t\t\t\t\t\t\t<region>MI</region>\n\t\t\t\t\t\t\t\t\t<country key="US">USA</country>\n\t\t\t\t\t\t\t\t</address>\n\t\t\t\t\t\t\t</affiliation>\n\t\t\t\t\t\t</author>\n\t\t\t\t\t\t<author>\n\t\t\t\t\t\t\t<persName><forename type="first">Haodong</forename><surname>Liang</surname></persName>\n\t\t\t\t\t\t\t<affiliation key="aff1">\n\t\t\t\t\t\t\t\t<orgName type="department" key="dep1">Department of Statistics</orgName>\n\t\t\t\t\t\t\t\t<orgName type="department" key="dep2">College of Literature, Science, and the Arts</orgName>\n\t\t\t\t\t\t\t\t<orgName type="institution">University of Michigan</orgName>\n\t\t\t\t\t\t\t\t<address>\n\t\t\t\t\t\t\t\t\t<settlement>Ann Arbor</settlement>\n\t\t\t\t\t\t\t\t\t<region>MI</region>\n\t\t\t\t\t\t\t\t\t<country key="US">USA</country>\n\t\t\t\t\t\t\t\t</address>\n\t\t\t\t\t\t\t</affiliation>\n\t\t\t\t\t\t</author>\n\t\t\t\t\t\t<author>\n\t\t\t\t\t\t\t<persName><forename type="first">Qianhui</forename><surname>Huang</surname></persName>\n\t\t\t\t\t\t\t<affiliation key="aff0">\n\t\t\t\t\t\t\t\t<orgName type="department" key="dep1">Department of Computational Medicine and Bioinformatics</orgName>\n\t\t\t\t\t\t\t\t<orgName type="department" key="dep2">Medical School</orgName>\n\t\t\t\t\t\t\t\t<orgName type="institution">University of Michigan</orgName>\n\t\t\t\t\t\t\t\t<address>\n\t\t\t\t\t\t\t\t\t<settlement>Ann Arbor</settlement>\n\t\t\t\t\t\t\t\t\t<region>MI</region>\n\t\t\t\t\t\t\t\t\t<country key="US">USA</country>\n\t\t\t\t\t\t\t\t</address>\n\t\t\t\t\t\t\t</affiliation>\n\t\t\t\t\t\t</author>\n\t\t\t\t\t\t<author>\n\t\t\t\t\t\t\t<persName><forename type="first">Yuheng</forename><surname>Du</surname></persName>\n\t\t\t\t\t\t\t<affiliation key="aff0">\n\t\t\t\t\t\t\t\t<orgName type="department" key="dep1">Department of Computational Medicine and Bioinformatics</orgName>\n\t\t\t\t\t\t\t\t<orgName type="department" key="dep2">Medical School</orgName>\n\t\t\t\t\t\t\t\t<orgName type="institution">University of Michigan</orgName>\n\t\t\t\t\t\t\t\t<address>\n\t\t\t\t\t\t\t\t\t ...

# %% [markdown]
# Check output for the first exception in futures_map dictionary above with Exception('[BAD_INPUT_DATA] PDF to XML conversion failed with error code: 1').

# %%
dl_pdf_xml[3]
# Out:
# '1'

# %% [markdown]
# ## 5. Clean and return XML as Beautiful Soup object
#
# Function to remove XML namespaces (xmlns) attribute and return the cleaned, parsed text as a [Beautiful Soup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) object. This object represents the document as a nested data structure so that we can navigate and extract text using XML tags.
#
# The simplest way to navigate the parse tree is to find a tag by name so we will use the find() method to return the XML for the `<body>` tag content.

# %%
# remove xmlns references from XML and convert to soup object

def soupify(text):
    cleaned_text = re.sub('\s*xmlns(:\w+)?=\"[^\"]*\"', '', text)
    return  BeautifulSoup(cleaned_text, 'lxml-xml').find("body")

# %% [markdown]
# View output for a 'soupified' article.

# %%
soupify_article_6 = soupify(dl_pdf_xml[6])
soupify_article_6
# Out:
# <body>
# <div><head>INTRODUCTION</head><p>The global impact of the COVID-19 pandemic on both human health and socioeconomic activity has brought to light the importance of a nuanced understanding of the way that epidemics spread in cities. Urban spread of disease is inherently tied to human mobility: as we move through and between cities, we serve as vectors that allow disease to spread to new individuals and communities. The nature of the relationship between mobility and spread of disease has been extensively studied; it is widely understood that human travel is a driving force behind disease spread <ref target="#b0" type="bibr">[1]</ref><ref target="#b1" type="bibr">[2]</ref><ref target="#b2" type="bibr">[3]</ref><ref target="#b3" type="bibr">[4]</ref><ref target="#b4" type="bibr">[5]</ref>. For this reason, many public policy interventions implemented worldwide to contain the spread of COVID-19 focused on limiting mobility, restricting the radius that individuals could travel from their homes and limiting travel between cities and countries.</p><p>As we continue to learn more about the ways that humans move, it is important to apply new discoveries about human mobility to the study of disease spread, deepening our understanding of urban epidemics for use in future public health crises. Recent research uncovered a clear, universal pattern in urban mobility: the total distance that the average visitor to a given location travels to reach it is constant across a city, unrelated to the lo-cation's overall attractiveness <ref target="#b5" type="bibr">[6]</ref>. This value, equivalent to the distance of a location to an individual's home multiplied by the number of times that they visit it over the course of some time period, can be thought of as an "exploration velocity": it is the effective distance individuals travel towards any given location per unit of time. It is a simple but critical parameter to understanding human movement.</p><p>Given the simplicity and apparent universality of this parameter of human mobility, its relationship to disease spread is a natural next question. Many travel restrictions and recommendations during the 2020 and 2021 COVID-19 pandemic focused on confining movements to a certain geographical area-for example, restricting the radius that people are able to travel to one's neighborhood, city, state, or country. But what if speed of disease spread depends not just on radius of travel r, but also on the product v := r • f ? If v has additional impact on disease spread, beyond average travel radius r, COVID-19 policies and restrictions that focused solely on restricting radius may have left significant unmet potential for further disease mitigation. This paper investigates the relationship between exploration velocity v := r • f and spread of disease, opening the door to future research on the ways in which that relationship can be utilized to contain epidemics.</p></div>
# <div><head>RESULTS</head><p>Simulating reduction of exploration velocity on real data. In order to understand how v = r • f interacts with speed of disease spread, we start with largescale datasets of individual human movements in New York City and Dakar, Senegal, which we call M real . The datasets each consist of a set of trips for N individuals over different time periods T , where each trip indicates a given individual moving between two locations. We then use agent based susceptible-infected (SI), susceptible-infected-recovered (SIR), and susceptibleexposed-infected-recovered (SEIR) models calibrated with estimates for COVID-19 <ref target="#b6" type="bibr">[7]</ref> to simulate disease spread as agents follow the trajectories in our datasets. Aside from their unique trajectories, each individual is assumed identical. In each simulation, we vary two parameters: the maximum travel distance r, measured relative to each agent's home location (see Methods for details), and the travel frequency f , the maximum number of times each location was visited. By varying these two parameters together, we are able to manually adjust exploration velocity v in the system. In practice, this means discarding any trip of length greater than r and all but f randomly selected trips to a given location from our datasets. The details of the spatial partitionings used as well as other simulation details are given in the Methods.</p><p>Figures <ref target="#fig_7" type="figure">1(a</ref>) and (b) plot the time it takes for the disease to reach some set proportion τ of the population against exploration velocity for each dataset. The value of τ is set to 29% for our Dakar data and 57% for our New York City data. Thresholds are chosen to be the total epidemic size at the end of the study period under the strictest restrictions for each study area, respectively. Simulations were run over the entire length of the datasets (14 days for the Dakar dataset; 28 days for New York City) with 10,000 agents and a 5% initial infected population. The trends are intuitive and not surprising. For a given f , τ decreases monotonically with r: the further people are allowed travel, the faster the epidemic spreads. Similarly, for a given r, τ decreases monotonically with f : more frequent return trips leads to faster-spreading epidemics. What is surprising, however, is that the τ (r) curves for each value of f have similar shape. This echoes a previous finding <ref target="#b5" type="bibr">[6]</ref> and hints that τ, r and f might have a simple relationship. Figures 1(c) and (d) show that they do. Under the rescaling r → r •f all the data appear to merge, collapsing to a single curve that depends on the unifying factor v := r • f , or exploration velocity. This curve can be empirically characterized as</p><formula xml:id="formula_0">τ (r • f ) = (r • f ) a • b</formula><p>where a and b vary across cities and model types. Figure <ref type="figure">5</ref> in the Supplementary Material shows the same scaling collapse is achieved when the SI and SIR models are used, and Figure <ref type="figure">6</ref> in the SM shows it persists for different values of the disease parameter R 0 . Taken together, these findings suggest the r → r•f collapse persists across multiple disease processes.</p><p>After observing the relationship between r • f and epidemic size, we check whether there is a relationship between r • f and spatial dispersion of the disease. We analyze the spatial concentration of infected persons in our New York City simulations using the M function developed by Marcon and Puech, which is calculated as a function of some radius k around each agent <ref target="#b7" type="bibr">[8]</ref>-see Methods for a detailed description of this statistic. High M indicates tighter clusters of cases; low M indicates a more homogeneous distribution of cases across space. We find that for a given radius k, as r and f increase, M (k, r, f ) decreases: infections become consistent ...
# <div><head>Mechanisms.</head><p>In order to illustrate the potential mechanism by which r • f determines disease spread time, we assess the relationship between r•f and both number and variance of contacts between agents in our simulations. Think of our simulations as a network, where agents are nodes and edges are formed whenever two agents come within some distance of one another, enabling disease transmission. It is a known result of the SIR model that speed at which a disease spreads through a network of individuals depends not only on the average degree, or number of contacts per individual k , but also on the variance of contacts (via k 2 , or mean squared degree) according to the following relation:</p><formula xml:id="formula_1">τ = k k 2 − (γ + β) k ,</formula><p>where τ is the characteristic time, or time it takes for the disease to reach 1/e = 36% of the population, γ is the daily recovery parameter and β is the infection parameter. This relation isn't perfectly applicable to our context-it assumes exposure to all contacts at all timesteps, whereas our simulations incorporate movement in space and thus non-constant degree k over time. However, it is valuable in illustrating the effects of restricting r and f in our dataset. Restricting radius of travel r and frequency of return f affects both k and k 2 . The closer you stay to home and the fewer trips you take, the fewer unique individuals you have the opportunity to encounter (reducing average number of contacts k ). Further, as stricter restrictions are enforced, high-r, high-f trips are removed and the mobility patterns of high-frequency, long-distance travellers start to look more like the mobility patterns of low-frequency travellers who stay close to home (reducing variance of contacts k 2 ). Figure <ref target="#fig_3" type="figure">3</ref> plots these relationships in our New York City data, showing exploration velocity r • f on the x-axis against average number of contacts k and average squared number of contacts k 2 on the y-axis in panels a and b, respectively. Again, we see a logarithmic relationship. Plugging both k and k 2 into the relation above, we see that characteristic time as predicted by the degree distribution (τ ) is proportional to the true characteristic time (τ ) that we see in our simulations -Figure <ref target="#fig_3" type="figure">3</ref>, panel c. Taken together, these findings show that the shape of the relationship between r • f and τ can be predicted by decreases in number and variance of contacts between agents in combination with fundamental SIR modeling results.</p><p>These results can be replicated by a simple modification of the preferential exploration and preferential return (PEPR) mobility model presented in previous literature <ref target="#b5" type="bibr">[6]</ref>. Under the PEPR model as proposed in <ref target="#b5" type="bibr">[6]</ref>, at each timestep, agents either explore a new location with a fixed probability P new or return to a previously-visited location with complementary probability 1 − P new . In order to choose a new location, agents draw a radius of travel ∆r from a heavy-tailed distribution with exponent P (∆r) ∼ |∆r| −1−α , with α = 0.55 taken from <ref target="#b5" type="bibr">[6]</ref>, and they draw an angle of travel θ with preference towards θ that are heavily visited by other agents (see Methods for details). As demonstrated in <ref target="#b5" type="bibr">[6]</ref>, the PEPR model replicates the universality of r • f . However, when we run our SEIR model on mobility trajectories simulated with the PEPR model, we do not see the same relationship between r • f and τ that we see in our real data. This is because, in the original PEPR model, agents are always moving from place to place without necessarily returning home, whereas in our real mobility trajectories, time spent at home means less exposure to new, unique contacts (and more exposure to the same neighbors). This leads to the PEPR model b ...
# <div><head>DISCUSSION</head><p>The significance of r • f was revealed in recent work <ref target="#b5" type="bibr">[6]</ref> on human mobility patterns which shows the number of people who visit a given location f times from a distance r during a certain reference period follow a universal, inverse square law N (r, f ) ∝ 1/(rf ) 2 . We suspect the τ (rf ) curve found in this paper derives from this inverse square law; while we have discussed the relationship between exploration velocity and network contacts, deriving the exact mechanism linking the universal inverse square law to τ (rf ) is an open question for future work.</p><p>An important implication of the τ (r • f ) curve is that restricting short, high frequency trips in a simulated environment does as much to slow disease spread as restricting long, low frequency trips. Agents in our simulations that take multiple trips around their neighbourhood spread disease as quickly as a those taking single, long trips to the city center. This is interesting academically, but more importantly, it has potential implications for policy: it means that restricting travel distance r but ignoring travel frequency f could be ineffective in containing the spreading of a disease.</p><p>That said, an important limitation of this study is that it restricts exploration velocity in a very specific way, removing trips that extend beyond a certain r or f . In reality, it is unclear how people would respond to policies that aim to restrict exploration velocity. True behavioral responses to different travel policies and what policies or mechanisms would be required to change individuals' behavior in a way that reduces exploration velocity are areas for future research. Further limitations of this study include the inherent limitations of simple epidemiological modeling; it is known that the SI, SIR, SEIR and other classic disease models make assumptions which bound their accuracy <ref target="#b8" type="bibr">[9]</ref><ref target="#b9" type="bibr">[10]</ref><ref target="#b10" type="bibr">[11]</ref>. The estimates for the model parameters likely carry error <ref target="#b11" type="bibr">[12]</ref>, and we also assumed that each agent was identical and that each exposure within a set radius carried equal likelihood of infection. Moreover, the scale of our analysis is restricted to the city level (because our datasets are collected at this level) and so our findings do not necessarily generalize to the perhaps more important case of country-level and international travel policies. If the r • f invariance, or some form of inverse relation between r and f , holds for international mobility patterns, then, as at the city scale, lax distance limits could be compensated by strict frequency restrictions. This is a bold hypothesis, which should be tested in future work. Metapopulation disease models <ref target="#b12" type="bibr">[13]</ref><ref target="#b13" type="bibr">[14]</ref><ref target="#b14" type="bibr">[15]</ref>, with their convenient trade off between realism and parsimony, seem like a good theoretical starting point for this effort.</p><p>Despite these limitations, we believe our results reveal novel insights and bring up an important component of human mobility that could prove useful for future policies on COVID-19 and other epidemic diseases. In the current COVID-19 pandemic and in future pandemics, evidence-based policies at the city scale (not to mention the national or international scale) are needed to mitigate speed and intensity of disease spread. Our results have the potential to help this effort by opening up investigation into the relationship between exploration velocity and epidemic spread. They indicate that the exploration velocity of a city's inhabitants r • f must be boundedto bound distance r but not visitation frequency f leaves potential for disease containment unmet. Furthermore, and more optimistically, if a bound on exploration velocity is possible and effective, it woul ...
# <div><head>METHODS</head><p>New York City data. Individuals' movements in New York City are inferred from GPS traces collected from mobile phones by the company X-Mode over a span of one month (February 2020). The raw data contains about 479,163 anonymized users; our analysis uses 10,000 users randomly selected from those that appear in the dataset every day in the month of February. Dakar data. The Dakar dataset is based on anonymized Call Detailed Records (CDR) provided by the Data for Development (D4D) Challenge. The detailed information of this dataset is provided in <ref target="#b15" type="bibr">[16]</ref>. Here, we use the SET2, which includes individual trajectories for 300,000 FIG. <ref type="figure">4</ref>: PEPR simulation results. When we run SEIR models across a set of trajectories M sim which have been created using the modified PEPR model with P travel = .25, we see a similar relationship between r • f and τ to that in our real trajectories M real . When we run SEIR models across trajectories which have been created using the original PEPR model (with P travel = 1), we do not see this relationship. sampled users in Senegal, and after the preprocess, we have 173,000 users and 173 cells in Dakar region during two weeks of January, 2013. We subselect for users who appear at least 200 times in the dataset to ensure that we have adequate information about their trajectories over the two weeks. Data preprocessing. The X-Mode data from NYC is generated on an very fine spatial and temporal scale, with exact latitude and longitude coordinate updates as frequently as every second. The CDR data from Dakar, on the other hand, are generated only for voice calls, text messages or data exchanges and therefore have limited resolution in time. The geographic location of the cell towers and their density determines the accuracy of location measurements through triangularization techniques. Therefore, the trajectories extracted from CDRs constitute a discrete approximation of the moving population M (x; y; t). There are several steps in preprocessing of the data before it can be suitable for use in our analysis, which vary between the X-Mode data and the CDR data.</p><p>The main steps for the NYC data are: i) We use density-based spatial clustering of applications with noise (DBSCAN) to group tightly-clustered latitude/longitude pairs in each individual's trajectory into locations <ref target="#b16" type="bibr">[17]</ref>. If a cluster of at least five latitude/longitude points exists such that no point is more than .0004 degrees (about 56 meters) from two other points in the cluster, those points are grouped together as a single location. ii) Each agent is assigned the DBSCAN cluster it visits most as its home location. iii) We drop all locations in the trajectory that have been visited for less than a minimum time τ min = 15min. iv) In order to restrict travel distance r, we calculate distance between locations by the haversine formula, which derives the great-circle distance between two points on a sphere. All locations that are more than r km from an agents home location are removed from their trajectory. v) In order to restrict travel frequency f , for each DBSCAN cluster that an agent visits more than f distinct times (where distinct visits are determined by an agent leaving a location and then coming back to it), we randomly select f visits to include in their trajectory and drop the rest.</p><p>The main steps for the Dakar data are: i) We view each cell tower as a different location in the city. ii) For each person, we determine the home location as the cell tower location which has been visited for the most cumulative time. By summing over all days in a given time window, one can find the home cell with high level of confidence for the majority of subjects. iii) We drop all locations in the trajectory that have been visited for less than a minimum time τ min = 10min. iv) In order to restrict travel distance r, we calculat ...
# <figure xml:id="fig_1"><head/><label/><figDesc>(a) Relationship between frequency restriction and dispersion for radius = 700m. (b) Scaling collapse for radius = 700m. R 2 value of best-fit line is .97.(c) Holding r constant but restricting f , we can see that loosening restrictions on f increases spatial dispersion of infections-when f is at 1 (left), infections reach 59.0% of grid cells; when f is relaxed to 6 (right), infections reach 73.8% of grid cells.(d) In the simulations above, r and f are individually different but r • f is the same. The similar spatial distribution of infections in the two simulations reflects the scaling collapse in dispersion of infection: dispersion depends on r • f as opposed to just r or f . Here, color represents proportion of the grid cell population that is infected at the end of the simulation.</figDesc></figure>
# <figure xml:id="fig_2"><head>FIG. 2 :</head><label>2</label><figDesc>FIG. 2:Scaling collapse of spatial dispersion of infections. Like τ , spatial dispersion M shows a universal scaling collapse with the product r • f , as demonstrated in panels (a) and (b). Here, M is calculated using a radius of k = 700 meters. This is visually represented in panel (c), where we see the final spatial distribution of infections for two simulations with the same r but different f , and in panel (d), where we see the final spatial distribution of infections for two simulations with the same r • f but different r and f .</figDesc><graphic coords="4,66.70,528.79,152.43,101.62" type="bitmap"/></figure>
# <figure xml:id="fig_3"><head>FIG. 3 :</head><label>3</label><figDesc>FIG.3: Relationship between spreading speed and number and variance of contacts. Both mean number of contacts k and mean squared number of contacts k 2 of the agents in our dataset show a clear logarithmic relationship with exploration velocity r • f . The relationship between r • f and k , k 2 can predict spreading speed τ using a simple relation that is a known result of the SIR model.</figDesc><graphic coords="4,231.83,528.79,152.43,101.62" type="bitmap"/></figure>
# <figure xml:id="fig_4"><head/><label/><figDesc>(a) Relationship between distance restriction and τ in PEPR simulations with P travel = .25. R 2 value of best fit line is .875. (b) Relationship between distance restriction and τ as predicted by k , k 2 in PEPR simulations with P travel = .25. R 2 value of best fit line is .924. (c) Relationship between distance restriction and τ in PEPR simulations with P travel = 1. R 2 value of best fit line is .640. (d) Relationship between distance restriction and τ as predicted by k , k 2 in PEPR simulations with P travel = 1. R 2 value of best fit line is .480.</figDesc></figure>
# <figure xml:id="fig_5"><head/><label/><figDesc>8 days: β = daily transmission parameter = 3.58 5.8 = .617 σ = daily rate at which an exposed person becomes infective = 1/5.2 γ = daily recovery parameter = 1/5.8 Let s be the number of time steps in a day. We then transform the above daily parameters into timestep parameters as follows: β * = time step transmission probability = β/s γ * = time step recovery probability = 1 − s √ 1 − γ σ * = time step probability that an exposed person becomes infective = 1 − s √ 1 − σ</figDesc></figure>
# <figure xml:id="fig_6"><head>FIG. 5 :FIG. 6 :FIG. 7 :</head><label>567</label><figDesc>FIG. 5: Scaling collapse in SI and SIR model. Top row: scaling collapse for SI model. R 2 values for best-fit lines are, from left to right, .958 and .896. Best-fit line parameters are a = −0.18, b = 1821.23 (NYC) and a = −0.04, b = 1797.87 (Dakar). Bottom row, scaling collapse for SIR model. R 2 values for best-fit lines are, from left to right, .974 and .937. Best-fit line parameters are a = −0.17, b = 1802.79 (NYC) and a = −0.04, b = 1760.42 (Dakar).</figDesc><graphic coords="10,70.94,229.91,228.64,152.43" type="bitmap"/></figure>
# <figure xml:id="fig_7"><head>( a )</head><label>a</label><figDesc>Relationship between distance restriction and τ in PEPR simulations. (b) Relationship between distance restriction and τ as predicted by k , k 2 in PEPR simulations.</figDesc></figure>
# <figure xml:id="fig_8"><head>FIG. 8 :</head><label>8</label><figDesc>FIG.8: PEPR simulation results, where P travel = .40. When we run SEIR models across a set of trajectories M sim which have been created using the PEPR model with P travel = .40, we see a similar relationship between r • f and τ to that in our real trajectories M real .</figDesc><graphic coords="11,70.94,440.95,228.64,152.43" type="bitmap"/></figure>
# </body>

# %%
soup_results_arxiv = list(map(soupify, dl_pdf_xml))

# %%
type(soup_results_arxiv)
# Out:
# list

# %%
len(soup_results_arxiv)
# Out:
# 304

# %% [markdown]
# ## 6. Navigating the tree
#
# A `<Tag>` object corresponds to an XML tag in the original document, in this case the `<body>` tag.

# %%
type(soup_results_arxiv[6])
# Out:
# bs4.element.Tag

# %% [markdown]
# To find the `<head`> tag we can just use the format soup.head

# %%
soup_results_arxiv[6].head
# Out:
# <head>INTRODUCTION</head>

# %% [markdown]
# View the result when returning the type of object for the first exception in futures_map dictionary above with Exception('[BAD_INPUT_DATA] PDF to XML conversion failed with error code: 1').

# %%
type(soup_results_arxiv[3])
# Out:
# NoneType

# %% [markdown]
# ## 7. Find all tags including descendants
#
# Previously we used the find() method for each article which gives only the *first* tag by that name as each article only has one `<body>` and `<head>` tag.
#
# The function below uses the find_all() method to return *all* of the direct child and descendant tags of the `<body>` tag for each article.

# %%
def find_all_tags(article):

    tags_list = []

    try:
        for tag in article.find_all(True):
            if tag.name != None:
              tags_list.append(tag.name)
    except Exception as e:
      print(e)


    return sorted(list(set(tags_list)))

# %%
all_tags = list(map(find_all_tags, soup_results_arxiv))
# Out:
# 'NoneType' object has no attribute 'find_all'
# 'NoneType' object has no attribute 'find_all'
# 'NoneType' object has no attribute 'find_all'
# 'NoneType' object has no attribute 'find_all'

# %% [markdown]
# As expected, these are the four exceptions we found earlier which show up as empty lists.

# %%
all_tags
# Out:
# [['div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  [],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'p', 'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'p', 'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'p', 'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'note', 'p', 'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'p', 'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'p', 'ref', 'table'],
#  ['div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'p', 'ref'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'p', 'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  [],
#  [],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'p'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'note', 'p', 'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'p', 'ref'],
#  ['div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'p', 'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'formula', 'head', 'label', 'p', 'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'p', 'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'p', 'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'head', 'p', 'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'note', 'p', 'ref'],
#  ['div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'p', 'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref'],
#  ['div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'p', 'ref'],
#  ['div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  [],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'note', 'p', 'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'p', 'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'p', 'ref'],
#  ['div', 'figDesc', 'figure', 'head', 'label', 'note', 'p', 'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'p', 'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'note', 'p', 'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'p', 'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'head', 'label', 'p', 'ref', 'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'p', 'ref'],
#  ['div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'p', 'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'p', 'ref'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'p', 'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'note', 'p', 'ref'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'note', 'p', 'ref'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'note', 'p', 'ref'],
#  ['div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'note', 'p', 'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'head', 'p', 'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'head', 'label', 'p', 'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'formula', 'head', 'label', 'note', 'p', 'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'p', 'ref'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'p', 'ref'],
#  ['div',
#   'figDesc',
#   'figure',
#   'formula',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref'],
#  ['cell',
#   'div',
#   'figDesc',
#   'figure',
#   'graphic',
#   'head',
#   'label',
#   'note',
#   'p',
#   'ref',
#   'row',
#   'table'],
#  ['div', 'figDesc', 'figure', 'graphic', 'head', 'label', 'p', 'ref']]

# %% [markdown]
# Sum function to take in all_tags nested list and return the sum of all elements as one list.

# %%
sum_all_tags = sum(all_tags, [])
sum_all_tags
# Out:
# ['div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'table',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'head',
#  'label',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  'label',
#  'note',
#  'p',
#  'ref',
#  'row',
#  'table',
#  'cell',
#  'div',
#  'figDesc',
#  'figure',
#  'formula',
#  'graphic',
#  'head',
#  ...]

# %% [markdown]
# Counter class with additional most_common() method to return a list of the *n* most common elements and their counts from the most common to the least.

# %%
num_all_unique_tags = Counter(sum_all_tags).most_common()
num_all_unique_tags = num_all_unique_tags[::]

for tag, count in num_all_unique_tags:
  print(tag, count)
# Out:
# div 300
# head 300
# p 300
# ref 299
# label 298
# figDesc 297
# figure 297
# graphic 249
# table 240
# cell 235
# row 235
# formula 179
# note 177

# %% [markdown]
# ## 8. Find direct child tags of `<body>` tag
#
# Every tag has a name which can be accessed using the `.name` attribute.
#
# We will use this to find the direct child tags of the `<body>` tag.

# %%
def find_body_child_tags(article):

    body_child_list = []

    try:
        for tag in article:
            if tag.name != None:
                  body_child_list.append(tag.name)
    except Exception as e:
        print(e)

    return sorted(list(set(body_child_list)))

# %%
body_child_tags = list(map(find_body_child_tags, soup_results_arxiv))
# Out:
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable

# %% [markdown]
# We can see below that the `<body>` tag has direct child tags for `<div>`, `<figure>` and `<note>`.

# %%
body_child_tags
# Out:
# [['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  [],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  [],
#  [],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  [],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure'],
#  ['div', 'figure', 'note'],
#  ['div', 'figure'],
#  ['div', 'figure']]

# %% [markdown]
# Sum function to take in body_child_tags nested list and return the sum of all elements as one list.

# %%
sum_body_child_tags = sum(body_child_tags, [])
sum_body_child_tags
# Out:
# ['div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'div',
#  'figure',
#  'note',
#  'div',
#  'figure',
#  'div',
#  'figure']

# %% [markdown]
# Again use the Counter class with most_common() method to return a list of the *n* most common elements and their counts from the most common to the least.

# %%
num_unique_body_child_tags = Counter(sum_body_child_tags).most_common()
num_unique_body_child_tags = num_unique_body_child_tags[::]

for tag, count in num_unique_body_child_tags:
  print(tag, count)
# Out:
# div 300
# figure 297
# note 105

# %% [markdown]
# ##  9. Find direct child tags of `<div>` tags
#
# Function to find all `<div>` tags and append all direct child tags to a list.

# %%
def find_div_tags(article):

    div_tags = []

    try:
        divs = article.find_all("div")
        for div in divs:
          for tag in div:
              if tag.name != None:
                  div_tags.append(tag.name)
    except Exception as e:
        print(e)

    return sorted(list(set(div_tags)))

# %%
div_tags = list(map(find_div_tags, soup_results_arxiv))
# Out:
# 'NoneType' object has no attribute 'find_all'
# 'NoneType' object has no attribute 'find_all'
# 'NoneType' object has no attribute 'find_all'
# 'NoneType' object has no attribute 'find_all'

# %%
div_tags
# Out:
# [['formula', 'head', 'note', 'p'],
#  ['head', 'p'],
#  ['head', 'note', 'p'],
#  [],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'note', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['head', 'note', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'note', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['head', 'note', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'note', 'p'],
#  ['formula', 'head', 'note', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  [],
#  [],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'note', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'note', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'note', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  [],
#  ['formula', 'head', 'note', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'note', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['head', 'note', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['head', 'note', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['head', 'p'],
#  ['formula', 'head', 'p'],
#  ['head', 'p'],
#  ['head', 'p']]

# %% [markdown]
# Sum function to take in div_tags nested list and return the sum of all elements as one list.

# %%
sum_div_tags = sum(div_tags, [])
sum_div_tags
# Out:
# ['formula',
#  'head',
#  'note',
#  'p',
#  'head',
#  'p',
#  'head',
#  'note',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'note',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'note',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'note',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'note',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'note',
#  'p',
#  'formula',
#  'head',
#  'note',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'note',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'note',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'note',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'note',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'note',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'note',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'note',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p',
#  'formula',
#  'head',
#  'p',
#  'head',
#  'p',
#  'head',
#  'p']

# %% [markdown]
# Again use the Counter class with most_common() method to return a list of the *n* most common elements and their counts from the most common to the least.

# %%
num_unique_div_tags = Counter(sum_div_tags).most_common()
num_unique_div_tags = num_unique_div_tags[::]

for tag, count in num_unique_div_tags:
  print(tag, count)
# Out:
# p 300
# head 297
# formula 179
# note 15

# %% [markdown]
# ## 10. Remove unwanted tags and content
#
# Define functions to remove unwanted tags and their contents using decompose() method which removes a tag from the tree, then completely destroys it and its contents.

# %%
def remove_headings(article):

    for head in article("head"):
        head.decompose()

    return article


def remove_figures(article):

    for figure in article("figure"):
        figure.decompose()

    return article

def remove_tables(article):

    for table in article("table"):
        table.decompose()

    return article

def remove_formulas(article):

    for formula in article("formula"):
        formula.decompose()

    return article


def remove_labels(article):

    for label in article("label"):
        label.decompose()

    return article


def remove_refs(article):

    for ref in article("ref"):
        ref.decompose()

    return article


def remove_graphics(article):

    for graphic in article("graphic"):
        graphic.decompose()

    return article


def remove_notes(article):

    for note in article("note"):
        note.decompose()

    return article

# %% [markdown]
# Function to call the functions above on each article and return new article list.

# %%
def remove_tags(article):

    new_article_list = []

    if article != None:
        try:
              new_article = remove_headings(article)
              new_article = remove_figures(new_article)
              new_article = remove_tables(new_article)
              new_article = remove_formulas(new_article)
              new_article = remove_labels(new_article)
              new_article = remove_refs(new_article)
              new_article = remove_graphics(article)
              new_article = remove_notes(article)
              new_article_list.append(new_article)
        except Exception as e:
            print(e)

    return new_article_list

# %%
soup_results_arxiv_removed_tags = list(map(remove_tags, soup_results_arxiv))

# %%
len(soup_results_arxiv_removed_tags)
# Out:
# 304

# %% [markdown]
# View article with unwanted tags and contents removed.

# %%
soup_results_arxiv_removed_tags[6]
# Out:
# [<body>
#  <div><p>The global impact of the COVID-19 pandemic on both human health and socioeconomic activity has brought to light the importance of a nuanced understanding of the way that epidemics spread in cities. Urban spread of disease is inherently tied to human mobility: as we move through and between cities, we serve as vectors that allow disease to spread to new individuals and communities. The nature of the relationship between mobility and spread of disease has been extensively studied; it is widely understood that human travel is a driving force behind disease spread . For this reason, many public policy interventions implemented worldwide to contain the spread of COVID-19 focused on limiting mobility, restricting the radius that individuals could travel from their homes and limiting travel between cities and countries.</p><p>As we continue to learn more about the ways that humans move, it is important to apply new discoveries about human mobility to the study of disease spread, deepening our understanding of urban epidemics for use in future public health crises. Recent research uncovered a clear, universal pattern in urban mobility: the total distance that the average visitor to a given location travels to reach it is constant across a city, unrelated to the lo-cation's overall attractiveness . This value, equivalent to the distance of a location to an individual's home multiplied by the number of times that they visit it over the course of some time period, can be thought of as an "exploration velocity": it is the effective distance individuals travel towards any given location per unit of time. It is a simple but critical parameter to understanding human movement.</p><p>Given the simplicity and apparent universality of this parameter of human mobility, its relationship to disease spread is a natural next question. Many travel restrictions and recommendations during the 2020 and 2021 COVID-19 pandemic focused on confining movements to a certain geographical area-for example, restricting the radius that people are able to travel to one's neighborhood, city, state, or country. But what if speed of disease spread depends not just on radius of travel r, but also on the product v := r • f ? If v has additional impact on disease spread, beyond average travel radius r, COVID-19 policies and restrictions that focused solely on restricting radius may have left significant unmet potential for further disease mitigation. This paper investigates the relationship between exploration velocity v := r • f and spread of disease, opening the door to future research on the ways in which that relationship can be utilized to contain epidemics.</p></div>
#  <div><p>Simulating reduction of exploration velocity on real data. In order to understand how v = r • f interacts with speed of disease spread, we start with largescale datasets of individual human movements in New York City and Dakar, Senegal, which we call M real . The datasets each consist of a set of trips for N individuals over different time periods T , where each trip indicates a given individual moving between two locations. We then use agent based susceptible-infected (SI), susceptible-infected-recovered (SIR), and susceptibleexposed-infected-recovered (SEIR) models calibrated with estimates for COVID-19  to simulate disease spread as agents follow the trajectories in our datasets. Aside from their unique trajectories, each individual is assumed identical. In each simulation, we vary two parameters: the maximum travel distance r, measured relative to each agent's home location (see Methods for details), and the travel frequency f , the maximum number of times each location was visited. By varying these two parameters together, we are able to manually adjust exploration velocity v in the system. In practice, this means discarding any trip of length greater than r and all but f randomly selected trips to a given location from our datasets. The details of the spatial partitionings used as well as other simulation details are given in the Methods.</p><p>Figures ) and (b) plot the time it takes for the disease to reach some set proportion τ of the population against exploration velocity for each dataset. The value of τ is set to 29% for our Dakar data and 57% for our New York City data. Thresholds are chosen to be the total epidemic size at the end of the study period under the strictest restrictions for each study area, respectively. Simulations were run over the entire length of the datasets (14 days for the Dakar dataset; 28 days for New York City) with 10,000 agents and a 5% initial infected population. The trends are intuitive and not surprising. For a given f , τ decreases monotonically with r: the further people are allowed travel, the faster the epidemic spreads. Similarly, for a given r, τ decreases monotonically with f : more frequent return trips leads to faster-spreading epidemics. What is surprising, however, is that the τ (r) curves for each value of f have similar shape. This echoes a previous finding  and hints that τ, r and f might have a simple relationship. Figures 1(c) and (d) show that they do. Under the rescaling r → r •f all the data appear to merge, collapsing to a single curve that depends on the unifying factor v := r • f , or exploration velocity. This curve can be empirically characterized as</p><p>where a and b vary across cities and model types. Figure  in the Supplementary Material shows the same scaling collapse is achieved when the SI and SIR models are used, and Figure  in the SM shows it persists for different values of the disease parameter R 0 . Taken together, these findings suggest the r → r•f collapse persists across multiple disease processes.</p><p>After observing the relationship between r • f and epidemic size, we check whether there is a relationship between r • f and spatial dispersion of the disease. We analyze the spatial concentration of infected persons in our New York City simulations using the M function developed by Marcon and Puech, which is calculated as a function of some radius k around each agent -see Methods for a detailed description of this statistic. High M indicates tighter clusters of cases; low M indicates a more homogeneous distribution of cases across space. We find that for a given radius k, as r and f increase, M (k, r, f ) decreases: infections become consistently more dispersed across the city (see Figure  for this relationship when k = 700m). As with epidemic size, under the rescaling r → r • f , this relationship collapses to a single curve, as shown in Figure . This indicates that restricting r • f is more effective than restricting r alone at conta ...
#  <div><p>In order to illustrate the potential mechanism by which r • f determines disease spread time, we assess the relationship between r•f and both number and variance of contacts between agents in our simulations. Think of our simulations as a network, where agents are nodes and edges are formed whenever two agents come within some distance of one another, enabling disease transmission. It is a known result of the SIR model that speed at which a disease spreads through a network of individuals depends not only on the average degree, or number of contacts per individual k , but also on the variance of contacts (via k 2 , or mean squared degree) according to the following relation:</p><p>where τ is the characteristic time, or time it takes for the disease to reach 1/e = 36% of the population, γ is the daily recovery parameter and β is the infection parameter. This relation isn't perfectly applicable to our context-it assumes exposure to all contacts at all timesteps, whereas our simulations incorporate movement in space and thus non-constant degree k over time. However, it is valuable in illustrating the effects of restricting r and f in our dataset. Restricting radius of travel r and frequency of return f affects both k and k 2 . The closer you stay to home and the fewer trips you take, the fewer unique individuals you have the opportunity to encounter (reducing average number of contacts k ). Further, as stricter restrictions are enforced, high-r, high-f trips are removed and the mobility patterns of high-frequency, long-distance travellers start to look more like the mobility patterns of low-frequency travellers who stay close to home (reducing variance of contacts k 2 ). Figure  plots these relationships in our New York City data, showing exploration velocity r • f on the x-axis against average number of contacts k and average squared number of contacts k 2 on the y-axis in panels a and b, respectively. Again, we see a logarithmic relationship. Plugging both k and k 2 into the relation above, we see that characteristic time as predicted by the degree distribution (τ ) is proportional to the true characteristic time (τ ) that we see in our simulations -Figure , panel c. Taken together, these findings show that the shape of the relationship between r • f and τ can be predicted by decreases in number and variance of contacts between agents in combination with fundamental SIR modeling results.</p><p>These results can be replicated by a simple modification of the preferential exploration and preferential return (PEPR) mobility model presented in previous literature . Under the PEPR model as proposed in , at each timestep, agents either explore a new location with a fixed probability P new or return to a previously-visited location with complementary probability 1 − P new . In order to choose a new location, agents draw a radius of travel ∆r from a heavy-tailed distribution with exponent P (∆r) ∼ |∆r| −1−α , with α = 0.55 taken from , and they draw an angle of travel θ with preference towards θ that are heavily visited by other agents (see Methods for details). As demonstrated in , the PEPR model replicates the universality of r • f . However, when we run our SEIR model on mobility trajectories simulated with the PEPR model, we do not see the same relationship between r • f and τ that we see in our real data. This is because, in the original PEPR model, agents are always moving from place to place without necessarily returning home, whereas in our real mobility trajectories, time spent at home means less exposure to new, unique contacts (and more exposure to the same neighbors). This leads to the PEPR model being unable to replicate the changes in k that are associated with loosening or tightening radius restrictions, as seen in Figures  and. In order to correct for this, we add a probability of travel P travel -at each timestep, with probability P travel , the agent travels to a new location according to the protocol above, w ...
#  <div><p>The significance of r • f was revealed in recent work  on human mobility patterns which shows the number of people who visit a given location f times from a distance r during a certain reference period follow a universal, inverse square law N (r, f ) ∝ 1/(rf ) 2 . We suspect the τ (rf ) curve found in this paper derives from this inverse square law; while we have discussed the relationship between exploration velocity and network contacts, deriving the exact mechanism linking the universal inverse square law to τ (rf ) is an open question for future work.</p><p>An important implication of the τ (r • f ) curve is that restricting short, high frequency trips in a simulated environment does as much to slow disease spread as restricting long, low frequency trips. Agents in our simulations that take multiple trips around their neighbourhood spread disease as quickly as a those taking single, long trips to the city center. This is interesting academically, but more importantly, it has potential implications for policy: it means that restricting travel distance r but ignoring travel frequency f could be ineffective in containing the spreading of a disease.</p><p>That said, an important limitation of this study is that it restricts exploration velocity in a very specific way, removing trips that extend beyond a certain r or f . In reality, it is unclear how people would respond to policies that aim to restrict exploration velocity. True behavioral responses to different travel policies and what policies or mechanisms would be required to change individuals' behavior in a way that reduces exploration velocity are areas for future research. Further limitations of this study include the inherent limitations of simple epidemiological modeling; it is known that the SI, SIR, SEIR and other classic disease models make assumptions which bound their accuracy . The estimates for the model parameters likely carry error , and we also assumed that each agent was identical and that each exposure within a set radius carried equal likelihood of infection. Moreover, the scale of our analysis is restricted to the city level (because our datasets are collected at this level) and so our findings do not necessarily generalize to the perhaps more important case of country-level and international travel policies. If the r • f invariance, or some form of inverse relation between r and f , holds for international mobility patterns, then, as at the city scale, lax distance limits could be compensated by strict frequency restrictions. This is a bold hypothesis, which should be tested in future work. Metapopulation disease models , with their convenient trade off between realism and parsimony, seem like a good theoretical starting point for this effort.</p><p>Despite these limitations, we believe our results reveal novel insights and bring up an important component of human mobility that could prove useful for future policies on COVID-19 and other epidemic diseases. In the current COVID-19 pandemic and in future pandemics, evidence-based policies at the city scale (not to mention the national or international scale) are needed to mitigate speed and intensity of disease spread. Our results have the potential to help this effort by opening up investigation into the relationship between exploration velocity and epidemic spread. They indicate that the exploration velocity of a city's inhabitants r • f must be boundedto bound distance r but not visitation frequency f leaves potential for disease containment unmet. Furthermore, and more optimistically, if a bound on exploration velocity is possible and effective, it would mean that strict distance restrictions at the city or town level -as adopted by, e.g., Ireland and Italy at the beginning of the infection -are perhaps unnecessary. Given a desired bound on epidemic speed τ bound , a large r could be offset by a small f ; allowing citizens to travel infrequently to distant services (doctors, hospitals etc) m ...
#  <div><p>New York City data. Individuals' movements in New York City are inferred from GPS traces collected from mobile phones by the company X-Mode over a span of one month (February 2020). The raw data contains about 479,163 anonymized users; our analysis uses 10,000 users randomly selected from those that appear in the dataset every day in the month of February. Dakar data. The Dakar dataset is based on anonymized Call Detailed Records (CDR) provided by the Data for Development (D4D) Challenge. The detailed information of this dataset is provided in . Here, we use the SET2, which includes individual trajectories for 300,000 FIG. : PEPR simulation results. When we run SEIR models across a set of trajectories M sim which have been created using the modified PEPR model with P travel = .25, we see a similar relationship between r • f and τ to that in our real trajectories M real . When we run SEIR models across trajectories which have been created using the original PEPR model (with P travel = 1), we do not see this relationship. sampled users in Senegal, and after the preprocess, we have 173,000 users and 173 cells in Dakar region during two weeks of January, 2013. We subselect for users who appear at least 200 times in the dataset to ensure that we have adequate information about their trajectories over the two weeks. Data preprocessing. The X-Mode data from NYC is generated on an very fine spatial and temporal scale, with exact latitude and longitude coordinate updates as frequently as every second. The CDR data from Dakar, on the other hand, are generated only for voice calls, text messages or data exchanges and therefore have limited resolution in time. The geographic location of the cell towers and their density determines the accuracy of location measurements through triangularization techniques. Therefore, the trajectories extracted from CDRs constitute a discrete approximation of the moving population M (x; y; t). There are several steps in preprocessing of the data before it can be suitable for use in our analysis, which vary between the X-Mode data and the CDR data.</p><p>The main steps for the NYC data are: i) We use density-based spatial clustering of applications with noise (DBSCAN) to group tightly-clustered latitude/longitude pairs in each individual's trajectory into locations . If a cluster of at least five latitude/longitude points exists such that no point is more than .0004 degrees (about 56 meters) from two other points in the cluster, those points are grouped together as a single location. ii) Each agent is assigned the DBSCAN cluster it visits most as its home location. iii) We drop all locations in the trajectory that have been visited for less than a minimum time τ min = 15min. iv) In order to restrict travel distance r, we calculate distance between locations by the haversine formula, which derives the great-circle distance between two points on a sphere. All locations that are more than r km from an agents home location are removed from their trajectory. v) In order to restrict travel frequency f , for each DBSCAN cluster that an agent visits more than f distinct times (where distinct visits are determined by an agent leaving a location and then coming back to it), we randomly select f visits to include in their trajectory and drop the rest.</p><p>The main steps for the Dakar data are: i) We view each cell tower as a different location in the city. ii) For each person, we determine the home location as the cell tower location which has been visited for the most cumulative time. By summing over all days in a given time window, one can find the home cell with high level of confidence for the majority of subjects. iii) We drop all locations in the trajectory that have been visited for less than a minimum time τ min = 10min. iv) In order to restrict travel distance r, we calculate distance between cell towers by the haversine formula, which derives the great-circle distance between two points on a sphere ...
#
#
#
#
#
#
#
#
#  </body>]

# %% [markdown]
# And one with Exception('[BAD_INPUT_DATA] PDF to XML conversion failed with error code: 1').

# %%
soup_results_arxiv_removed_tags[3]
# Out:
# []

# %% [markdown]
# ## 11.  Strip markup and keep text
#
# We only want to keep the human-readable text so we will use the get_text() method to return all the text in the articles as a single Unicode string without the `<body>`, `<div>` and `<p>` tags.

# %%
def strip_markup(articles):

    for article in articles:

        return article.get_text()

# %%
stripped_markup_articles = list(map(strip_markup, soup_results_arxiv_removed_tags))

# %%
len(stripped_markup_articles)
# Out:
# 304

# %% [markdown]
# View article with all tags removed.

# %%
stripped_markup_articles[6]
# Out:
# '\nThe global impact of the COVID-19 pandemic on both human health and socioeconomic activity has brought to light the importance of a nuanced understanding of the way that epidemics spread in cities. Urban spread of disease is inherently tied to human mobility: as we move through and between cities, we serve as vectors that allow disease to spread to new individuals and communities. The nature of the relationship between mobility and spread of disease has been extensively studied; it is widely understood that human travel is a driving force behind disease spread . For this reason, many public policy interventions implemented worldwide to contain the spread of COVID-19 focused on limiting mobility, restricting the radius that individuals could travel from their homes and limiting travel between cities and countries.As we continue to learn more about the ways that humans move, it is important to apply new discoveries about human mobility to the study of disease spread, deepening our understanding of urban epidemics for use in future public health crises. Recent research uncovered a clear, universal pattern in urban mobility: the total distance that the average visitor to a given location travels to reach it is constant across a city, unrelated to the lo-cation\'s overall attractiveness . This value, equivalent to the distance of a location to an individual\'s home multiplied by the number of times that they visit it over the course of some time period, can be thought of as an "exploration velocity": it is the effective distance individuals travel towards any given location per unit of time. It is a simple but critical parameter to understanding human movement.Given the simplicity and apparent universality of this parameter of human mobility, its relationship to disease spread is a natural next question. Many travel restrictions and recommendations during the 2020 and 2021 COVID-19 pandemic focused on confining movements to a certain geographical area-for example, restricting the radius that people are able to travel to one\'s neighborhood, city, state, or country. But what if speed of disease spread depends not just on radius of travel r, but also on the product v := r • f ? If v has additional impact on disease spread, beyond average travel radius r, COVID-19 policies and restrictions that focused solely on restricting radius may have left significant unmet potential for further disease mitigation. This paper investigates the relationship between exploration velocity v := r • f and spread of disease, opening the door to future research on the ways in which that relationship can be utilized to contain epidemics.\nSimulating reduction of exploration velocity on real data. In order to understand how v = r • f interacts with speed of disease spread, we start with largescale datasets of individual human movements in New York City and Dakar, Senegal, which we call M real . The datasets each consist of a set of trips for N individuals over different time periods T , where each trip indicates a given individual moving between two locations. We then use agent based susceptible-infected (SI), susceptible-infected-recovered (SIR), and susceptibleexposed-infected-recovered (SEIR) models calibrated with estimates for COVID-19  to simulate disease spread as agents follow the trajectories in our datasets. Aside from their unique trajectories, each individual is assumed identical. In each simulation, we vary two parameters: the maximum travel distance r, measured relative to each agent\'s home location (see Methods for details), and the travel frequency f , the maximum number of times each location was visited. By varying these two parameters together, we are able to manually adjust exploration velocity v in the system. In practice, this means discarding any trip of length greater than r and all but f randomly selected trips to a given location from our datasets. The details of the spatial partitionings used as well as other simulation detail ...

# %%
print(stripped_markup_articles[3])
# Out:
# None

# %%
with open('2023-01-06_stripped_markup_articles_304.pickle', 'wb') as f:
  pickle.dump(stripped_markup_articles, f)

# %% [markdown]
# ## 12. Add extracted full text to DataFrame
#
# Read in  arXiv metadata.

# %%
article_results_arxiv_304 = pd.read_pickle('2023-01-06_arxiv_results_for_dl.pickle')
article_results_arxiv_304
# Out:
#          arxiv-id   published     revised  \
# 0    2109.06377v4  2021-09-14  2022-12-22
# 1    2212.09867v1  2022-12-19  2022-12-19
# 2    2212.09610v1  2022-12-19  2022-12-19
# 3    2212.00023v2  2022-11-30  2022-12-08
# 4    2212.03911v1  2022-12-07  2022-12-07
# ..            ...         ...         ...
# 299  2003.13665v1  2020-03-30  2020-03-30
# 300  2003.14258v1  2020-03-30  2020-03-30
# 301  2003.12454v1  2020-03-26  2020-03-26
# 302  2003.04524v1  2020-03-10  2020-03-10
# 303  2003.00751v1  2020-03-02  2020-03-02
#
#                                                  title journal  \
# 0    ASGARD: A Single-cell Guided pipeline to Aid R...    None
# 1    Detecting Contradictory COVID-19 Drug Efficacy...    None
# 2    Drying of Bio-colloidal Sessile Droplets: Adva...    None
# 3    Random Copolymer inverse design system orienti...    None
# 4    Analysis of Drug repurposing Knowledge graphs ...    None
# ..                                                 ...     ...
# 299  Genomics-guided molecular maps of coronavirus ...    None
# 300  Nanomechanical sonification of the 2019-nCoV c...    None
# 301  A Machine Learning alternative to placebo-cont...    None
# 302  Old Drugs for Newly Emerging Viral Disease, CO...    None
# 303  Regulation of interferon production as a poten...    None
#
#                                                authors   doi  \
# 0    Bing He, Yao Xiao, Haodong Liang, Qianhui Huan...  None
# 1    Daniel N. Sosa, Malavika Suresh, Christopher P...  None
# 2           Anusuya Pal, Amalesh Gope, Anupam Sengupta  None
# 3                                 Tianyu Wu, Yang Tang  None
# 4                                  Ajay Kumar Gogineni  None
# ..                                                 ...   ...
# 299                                    Gennadi Glinsky  None
# 300                                  Markus J. Buehler  None
# 301   Ezequiel Alvarez, Federico Lamagna, Manuel Szewc  None
# 302                                Mohammad Reza Dayer  None
# 303             Xiaobing Deng, Xiaoyu Yu, Jianfeng Pei  None
#
#                                       pdf_url
# 0    http://export.arxiv.org/pdf/2109.06377v4
# 1    http://export.arxiv.org/pdf/2212.09867v1
# 2    http://export.arxiv.org/pdf/2212.09610v1
# 3    http://export.arxiv.org/pdf/2212.00023v2
# 4    http://export.arxiv.org/pdf/2212.03911v1
# ..                                        ...
# 299  http://export.arxiv.org/pdf/2003.13665v1
# 300  http://export.arxiv.org/pdf/2003.14258v1
# 301  http://export.arxiv.org/pdf/2003.12454v1
# 302  http://export.arxiv.org/pdf/2003.04524v1
# 303  http://export.arxiv.org/pdf/2003.00751v1
#
# [304 rows x 8 columns]

# %% [markdown]
# Add full text with stripped markup as 'text' column to DataFrame.

# %%
article_results_arxiv_304['text'] = stripped_markup_articles
article_results_arxiv_304
# Out:
#          arxiv-id   published     revised  \
# 0    2109.06377v4  2021-09-14  2022-12-22
# 1    2212.09867v1  2022-12-19  2022-12-19
# 2    2212.09610v1  2022-12-19  2022-12-19
# 3    2212.00023v2  2022-11-30  2022-12-08
# 4    2212.03911v1  2022-12-07  2022-12-07
# ..            ...         ...         ...
# 299  2003.13665v1  2020-03-30  2020-03-30
# 300  2003.14258v1  2020-03-30  2020-03-30
# 301  2003.12454v1  2020-03-26  2020-03-26
# 302  2003.04524v1  2020-03-10  2020-03-10
# 303  2003.00751v1  2020-03-02  2020-03-02
#
#                                                  title journal  \
# 0    ASGARD: A Single-cell Guided pipeline to Aid R...    None
# 1    Detecting Contradictory COVID-19 Drug Efficacy...    None
# 2    Drying of Bio-colloidal Sessile Droplets: Adva...    None
# 3    Random Copolymer inverse design system orienti...    None
# 4    Analysis of Drug repurposing Knowledge graphs ...    None
# ..                                                 ...     ...
# 299  Genomics-guided molecular maps of coronavirus ...    None
# 300  Nanomechanical sonification of the 2019-nCoV c...    None
# 301  A Machine Learning alternative to placebo-cont...    None
# 302  Old Drugs for Newly Emerging Viral Disease, CO...    None
# 303  Regulation of interferon production as a poten...    None
#
#                                                authors   doi  \
# 0    Bing He, Yao Xiao, Haodong Liang, Qianhui Huan...  None
# 1    Daniel N. Sosa, Malavika Suresh, Christopher P...  None
# 2           Anusuya Pal, Amalesh Gope, Anupam Sengupta  None
# 3                                 Tianyu Wu, Yang Tang  None
# 4                                  Ajay Kumar Gogineni  None
# ..                                                 ...   ...
# 299                                    Gennadi Glinsky  None
# 300                                  Markus J. Buehler  None
# 301   Ezequiel Alvarez, Federico Lamagna, Manuel Szewc  None
# 302                                Mohammad Reza Dayer  None
# 303             Xiaobing Deng, Xiaoyu Yu, Jianfeng Pei  None
#
#                                       pdf_url  \
# 0    http://export.arxiv.org/pdf/2109.06377v4
# 1    http://export.arxiv.org/pdf/2212.09867v1
# 2    http://export.arxiv.org/pdf/2212.09610v1
# 3    http://export.arxiv.org/pdf/2212.00023v2
# 4    http://export.arxiv.org/pdf/2212.03911v1
# ..                                        ...
# 299  http://export.arxiv.org/pdf/2003.13665v1
# 300  http://export.arxiv.org/pdf/2003.14258v1
# 301  http://export.arxiv.org/pdf/2003.12454v1
# 302  http://export.arxiv.org/pdf/2003.04524v1
# 303  http://export.arxiv.org/pdf/2003.00751v1
#
#                                                   text
# 0    \nHeterogeneity, or more specifically, the div...
# 1    \nThe COVID-19 pandemic caused by the novel SA...
# 2    \nVirus Emulating Particles (VEP) White Blood ...
# 3                                                 None
# 4    \nIn the initial stages of a viral outbreak su...
# ..                                                 ...
# 299  \nCoronavirus pandemic 2020 caused by the newl...
# 300  \nProteins are the building blocks of virtuall...
# 301  \nCurrent and last decades research in drug di...
# 302  \nThe outbreak of coronavirus  in 2019-2020 is...
# 303  \nNovel Coronavirus SARS-CoV-2 is a single str...
#
# [304 rows x 9 columns]

# %%
with open('2023-01-06_article_results_arxiv_304_full_text.pickle', 'wb') as f:
  pickle.dump(article_results_arxiv_304, f)

# %% [markdown]
# ## 13. Check for missing text
#
# Concise summary of DataFrame to see if there are any articles with missing text.

# %%
article_results_arxiv_304.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   arxiv-id   304 non-null    object
#  1   published  304 non-null    object
#  2   revised    304 non-null    object
#  3   title      304 non-null    object
#  4   journal    39 non-null     object
#  5   authors    304 non-null    object
#  6   doi        63 non-null     object
#  7   pdf_url    304 non-null    object
#  8   text       300 non-null    object
# dtypes: object(9)
# memory usage: 21.5+ KB

# %% [markdown]
# As expected, the four with exceptions.

# %%
article_results_arxiv_304[article_results_arxiv_304['text'].isna()]
# Out:
#          arxiv-id   published     revised  \
# 3    2212.00023v2  2022-11-30  2022-12-08
# 69   2109.00100v4  2021-08-31  2021-09-07
# 70   2109.00435v3  2021-09-01  2021-09-07
# 176  2007.09186v3  2020-07-17  2020-10-07
#
#                                                  title journal  \
# 3    Random Copolymer inverse design system orienti...    None
# 69   Proceedings of KDD 2021 Workshop on Data-drive...    None
# 70   Proceedings of KDD 2020 Workshop on Data-drive...    None
# 176  AWS CORD-19 Search: A Neural Search Engine for...    None
#
#                                                authors   doi  \
# 3                                 Tianyu Wu, Yang Tang  None
# 69   Snehalkumar, S. Gaikwad, Shankar Iyer, Dalton ...  None
# 70   Snehalkumar, S. Gaikwad, Shankar Iyer, Dalton ...  None
# 176  Parminder Bhatia, Lan Liu, Kristjan Arumae, Ni...  None
#
#                                       pdf_url  text
# 3    http://export.arxiv.org/pdf/2212.00023v2  None
# 69   http://export.arxiv.org/pdf/2109.00100v4  None
# 70   http://export.arxiv.org/pdf/2109.00435v3  None
# 176  http://export.arxiv.org/pdf/2007.09186v3  None

# %% [markdown]
# We will drop the three that have no PDF and handle separately the valid PDF which GROBID failed to process.

# %%
article_results_arxiv_301 = article_results_arxiv_304.copy()

# %%
article_results_arxiv_301.drop([3,69,70], axis=0, inplace=True)
article_results_arxiv_301
# Out:
#          arxiv-id   published     revised  \
# 0    2109.06377v4  2021-09-14  2022-12-22
# 1    2212.09867v1  2022-12-19  2022-12-19
# 2    2212.09610v1  2022-12-19  2022-12-19
# 4    2212.03911v1  2022-12-07  2022-12-07
# 5    2212.01575v1  2022-12-03  2022-12-03
# ..            ...         ...         ...
# 299  2003.13665v1  2020-03-30  2020-03-30
# 300  2003.14258v1  2020-03-30  2020-03-30
# 301  2003.12454v1  2020-03-26  2020-03-26
# 302  2003.04524v1  2020-03-10  2020-03-10
# 303  2003.00751v1  2020-03-02  2020-03-02
#
#                                                  title journal  \
# 0    ASGARD: A Single-cell Guided pipeline to Aid R...    None
# 1    Detecting Contradictory COVID-19 Drug Efficacy...    None
# 2    Drying of Bio-colloidal Sessile Droplets: Adva...    None
# 4    Analysis of Drug repurposing Knowledge graphs ...    None
# 5    Multi-view deep learning based molecule design...    None
# ..                                                 ...     ...
# 299  Genomics-guided molecular maps of coronavirus ...    None
# 300  Nanomechanical sonification of the 2019-nCoV c...    None
# 301  A Machine Learning alternative to placebo-cont...    None
# 302  Old Drugs for Newly Emerging Viral Disease, CO...    None
# 303  Regulation of interferon production as a poten...    None
#
#                                                authors   doi  \
# 0    Bing He, Yao Xiao, Haodong Liang, Qianhui Huan...  None
# 1    Daniel N. Sosa, Malavika Suresh, Christopher P...  None
# 2           Anusuya Pal, Amalesh Gope, Anupam Sengupta  None
# 4                                  Ajay Kumar Gogineni  None
# 5    Chao Pang, Yu Wang, Yi Jiang, Ruheng Wang, Ran...  None
# ..                                                 ...   ...
# 299                                    Gennadi Glinsky  None
# 300                                  Markus J. Buehler  None
# 301   Ezequiel Alvarez, Federico Lamagna, Manuel Szewc  None
# 302                                Mohammad Reza Dayer  None
# 303             Xiaobing Deng, Xiaoyu Yu, Jianfeng Pei  None
#
#                                       pdf_url  \
# 0    http://export.arxiv.org/pdf/2109.06377v4
# 1    http://export.arxiv.org/pdf/2212.09867v1
# 2    http://export.arxiv.org/pdf/2212.09610v1
# 4    http://export.arxiv.org/pdf/2212.03911v1
# 5    http://export.arxiv.org/pdf/2212.01575v1
# ..                                        ...
# 299  http://export.arxiv.org/pdf/2003.13665v1
# 300  http://export.arxiv.org/pdf/2003.14258v1
# 301  http://export.arxiv.org/pdf/2003.12454v1
# 302  http://export.arxiv.org/pdf/2003.04524v1
# 303  http://export.arxiv.org/pdf/2003.00751v1
#
#                                                   text
# 0    \nHeterogeneity, or more specifically, the div...
# 1    \nThe COVID-19 pandemic caused by the novel SA...
# 2    \nVirus Emulating Particles (VEP) White Blood ...
# 4    \nIn the initial stages of a viral outbreak su...
# 5    \nDe novo drug design is a time-consuming and ...
# ..                                                 ...
# 299  \nCoronavirus pandemic 2020 caused by the newl...
# 300  \nProteins are the building blocks of virtuall...
# 301  \nCurrent and last decades research in drug di...
# 302  \nThe outbreak of coronavirus  in 2019-2020 is...
# 303  \nNovel Coronavirus SARS-CoV-2 is a single str...
#
# [301 rows x 9 columns]

# %%
len(article_results_arxiv_301)
# Out:
# 301

# %%
article_results_arxiv_301.reset_index(drop=True, inplace=True)

# %% [markdown]
# Check that the articles have been dropped and the reindexing has worked by seeing if the articles that were previously in rows 69 and 70 have gone.

# %%
article_results_arxiv_301.loc[68:71]
# Out:
#         arxiv-id   published     revised  \
# 68  2010.16413v3  2020-10-09  2021-09-05
# 69  2103.02843v2  2021-03-04  2021-09-04
# 70  2108.13764v1  2021-08-31  2021-08-31
# 71  2108.12150v1  2021-08-27  2021-08-27
#
#                                                 title  \
# 68  Artificial Intelligence (AI) in Action: Addres...
# 69  Pandemic Drugs at Pandemic Speed: Infrastructu...
# 70  Virtual screening of Microalgal compounds as p...
# 71  A Nested Multi-Scale Model for COVID-19 Viral ...
#
#                                               journal  \
# 68  Annual Review of Biomedical Data Science 4 (2021)
# 69            Interface Focus. 2021. 11 (6): 20210018
# 70                                               None
# 71                                               None
#
#                                               authors  \
# 68  Qingyu Chen, Robert Leaman, Alexis Allot, Ling...
# 69  Agastya P. Bhati, Shunzhou Wan, Dario Alfè, Au...
# 70                                   Ibrahim Mohammed
# 71     Bishal Chhetri, D. K. K Vamsi, Carani Sanjeevi
#
#                                          doi  \
# 68  10.1146/annurev-biodatasci-021821-061045
# 69                    10.1098/rsfs.2021.0018
# 70                                      None
# 71                                      None
#
#                                      pdf_url  \
# 68  http://export.arxiv.org/pdf/2010.16413v3
# 69  http://export.arxiv.org/pdf/2103.02843v2
# 70  http://export.arxiv.org/pdf/2108.13764v1
# 71  http://export.arxiv.org/pdf/2108.12150v1
#
#                                                  text
# 68  \nSince the initial reports of an outbreak of ...
# 69  \ndiscovery lie at the interface between machi...
# 70  \nCorona virus disease-19  is caused by Severe...
# 71  \nCOVID -19 is a contagious respiratory and va...

# %%
with open('2023-01-06_article_results_arxiv_301_full_text.pickle', 'wb') as f:
  pickle.dump(article_results_arxiv_301, f)

# %% [markdown]
# ### References
#
# * GROBID https://github.com/kermitt2/grobid
#
# * GROBID documentation https://grobid.readthedocs.io/
#
#
# * Python PDF parser for scientific publications: content and figures https://github.com/titipata/scipdf_parser
