# %% [markdown]
# # Data collection of arXiv full text article metadata

# %% [markdown]
# ## 1. Introduction
#
#  arXiv is a free distribution service and an open-access archive for nearly 2.4 million scholarly articles in the fields of physics, mathematics, computer science, quantitative biology, quantitative finance, statistics, electrical engineering and systems science, and economics. The articles are pre- and postprints approved for posting after moderation but not peer-reviewed by arXiv.
#
#  Metadata will be collected from [arXiv](https://arxiv.org/) for full text scientific papers via the [arXiv API](https://info.arxiv.org/help/api/index.html). The  query used for the project relates to COVID-19 and drug repurposing from 2019-2022.

# %% [markdown]
# ## 2. Install/import libraries

# %%
# !pip install arxiv

# %%
import pandas as pd
import pickle
import arxiv
import datetime
import time

# %% [markdown]
# ## 3. Download metadata
#
# Construct a function to download metadata using the [arXiv API](https://info.arxiv.org/help/api/index.html) to search the publications database for the following fields: 'arxiv-id', 'published', 'revised', 'title', 'journal', 'authors', 'doi', 'pdf_url', and convert the dictionary to a DataFrame.

# %%
# Python wrapper adapted from https://github.com/lukasschwab/arxiv.py

def get_results(search_query: str, date_from: str = None, date_until: str = None):

    # Create a DataFrame to populate while iterating
    article_results = pd.DataFrame({'arxiv-id':[],
                                'published':[],
                                'revised':[],
                                'title':[],
                                'journal':[],
                                'authors': [],
                                'doi':[],
                                'pdf_url':[]})

    results_generator = arxiv.Client(
      # the number of papers to fetch from arXiv per page of results.
      # The API's limit is 30,000 in slices of at most 2000 at a time.
      page_size=100,
      # the number of seconds to wait between requests for pages.
      # arXiv's Terms of Use ask that you "make no more than one request every three seconds."
      delay_seconds=3,
      # The number of times the client will retry a request that fails
      num_retries=3
    ).results(arxiv.Search(
      query = f'search_query={search_query}',
      max_results = float('inf'),
      sort_by = arxiv.SortCriterion.LastUpdatedDate,
      sort_order = arxiv.SortOrder.Descending,
    ))

    if date_from is not None and date_from > date_until:
        raise Exception("Check that date_from precedes date_until")

    for result in results_generator:
        if date_from is not None and result.published.strftime('%Y-%m-%d') < date_from:
          continue
        elif date_until is not None and result.published.strftime('%Y-%m-%d') > date_until:
          continue
        print(f"arxiv-id: {result.entry_id.split('/abs/')[-1]}")
        print(f"published: {result.published.strftime('%Y-%m-%d')}")
        print(f"revised: {result.updated.strftime('%Y-%m-%d')}")
        print(f"title: {result.title}")
        print(f"journal: {result.journal_ref}")
        print(f"authors: {', '.join(author.name for author in result.authors)}")
        print(f"doi: {result.doi}")
        print(f"pdf_url: {result.pdf_url}")

        tmpdic = {'arxiv-id': result.entry_id.split('/abs/')[-1], 'published': result.published.strftime('%Y-%m-%d'),
        'revised': result.updated.strftime('%Y-%m-%d'), 'title': result.title, 'journal': result.journal_ref,
        'authors': ', '.join(author.name for author in result.authors), 'doi': result.doi, 'pdf_url': result.pdf_url}
        article_results = article_results.append(pd.DataFrame(tmpdic, index=[0]))
        article_results.reset_index(drop=True, inplace=True)


    return article_results

# %% [markdown]
# ## 4. Construct search query
#
# In the arXiv search engine, each article is divided up into a number of fields that can be searched by prepending the field prefix, followed by a colon, to the search term.
#
# The API allows advanced query construction by combining these search fields with Boolean operators (AND, OR, ANDNOT) and, for even more complex queries, by using parentheses for grouping the Boolean expressions.
#
# For advanced query syntax documentation, see the [arXiv API User's Manual](https://arxiv.org/help/api/user-manual#query_details).

# %%
search_query = "(all:covid OR all:coronavirus OR all:sars-cov-2) AND (all:'drug discovery' OR all:'drug repurposing' OR all:'drug repositioning')"
date_from = None
date_until = '2022-12-31'

article_results = get_results(search_query, date_from, date_until)
# Out:
# arxiv-id: 2109.06377v4
# published: 2021-09-14
# revised: 2022-12-22
# title: ASGARD: A Single-cell Guided pipeline to Aid Repurposing of Drugs
# journal: None
# authors: Bing He, Yao Xiao, Haodong Liang, Qianhui Huang, Yuheng Du, Yijun Li, David Garmire, Duxin Sun, Lana X. Garmire
# doi: None
# pdf_url: http://arxiv.org/pdf/2109.06377v4
# arxiv-id: 2212.09867v1
# published: 2022-12-19
# revised: 2022-12-19
# title: Detecting Contradictory COVID-19 Drug Efficacy Claims from Biomedical Literature
# journal: None
# authors: Daniel N. Sosa, Malavika Suresh, Christopher Potts, Russ B. Altman
# doi: None
# pdf_url: http://arxiv.org/pdf/2212.09867v1
# arxiv-id: 2212.09610v1
# published: 2022-12-19
# revised: 2022-12-19
# title: Drying of Bio-colloidal Sessile Droplets: Advances, Applications, and Perspectives
# journal: None
# authors: Anusuya Pal, Amalesh Gope, Anupam Sengupta
# doi: None
# pdf_url: http://arxiv.org/pdf/2212.09610v1
# arxiv-id: 2212.00023v2
# published: 2022-11-30
# revised: 2022-12-08
# title: Random Copolymer inverse design system orienting on Accurate discovering of Antimicrobial peptide-mimetic copolymers
# journal: None
# authors: Tianyu Wu, Yang Tang
# doi: None
# pdf_url: http://arxiv.org/pdf/2212.00023v2
# arxiv-id: 2212.03911v1
# published: 2022-12-07
# revised: 2022-12-07
# title: Analysis of Drug repurposing Knowledge graphs for Covid-19
# journal: None
# authors: Ajay Kumar Gogineni
# doi: None
# pdf_url: http://arxiv.org/pdf/2212.03911v1
# arxiv-id: 2212.01575v1
# published: 2022-12-03
# revised: 2022-12-03
# title: Multi-view deep learning based molecule design and structural optimization accelerates the SARS-CoV-2 inhibitor discovery
# journal: None
# authors: Chao Pang, Yu Wang, Yi Jiang, Ruheng Wang, Ran Su, Leyi Wei
# doi: None
# pdf_url: http://arxiv.org/pdf/2212.01575v1
# arxiv-id: 2103.02009v2
# published: 2021-03-02
# revised: 2022-12-01
# title: Travel distance, frequency of return and the spread of disease
# journal: None
# authors: Cate Heine, Kevin P. O'Keeffe, Paolo Santi, Li Yan, Carlo Ratti
# doi: None
# pdf_url: http://arxiv.org/pdf/2103.02009v2
# arxiv-id: 2204.08697v2
# published: 2022-04-19
# revised: 2022-11-29
# title: A Multi-Opinion Based Method for Quantifying Polarization on Social Networks
# journal: None
# authors: Maneet Singh, S. R. S. Iyengar, Rishemjit Kaur
# doi: None
# pdf_url: http://arxiv.org/pdf/2204.08697v2
# arxiv-id: 2207.09551v2
# published: 2022-07-19
# revised: 2022-11-23
# title: A mechanistic model to assess the effectiveness of test-trace-isolate-and-quarantine under limited capacities
# journal: None
# authors: Julian Heidecke, Jan Fuhrmann, Maria Vittoria Barbarossa
# doi: None
# pdf_url: http://arxiv.org/pdf/2207.09551v2
# arxiv-id: 2107.02905v2
# published: 2021-07-05
# revised: 2022-11-23
# title: An in silico drug repurposing pipeline to identify drugs with the potential to inhibit SARS-CoV-2 replication
# journal: None
# authors: Méabh MacMahon, Woochang Hwang, Soorin Yim, Eoghan MacMahon, Alexandre Abraham, Justin Barton, Mukunthan Tharmakulasingam, Paul Bilokon, Vasanthi Priyadarshini Gaddi, Namshik Han
# doi: None
# pdf_url: http://arxiv.org/pdf/2107.02905v2
# arxiv-id: 2211.00201v2
# published: 2022-11-01
# revised: 2022-11-16
# title: CCS Explorer: Relevance Prediction, Extractive Summarization, and Named Entity Recognition from Clinical Cohort Studies
# journal: None
# authors: Irfan Al-Hussaini, Davi Nakajima An, Albert J. Lee, Sarah Bi, Cassie S. Mitchell
# doi: None
# pdf_url: http://arxiv.org/pdf/2211.00201v2
# arxiv-id: 2011.11576v3
# published: 2020-11-23
# revised: 2022-10-24
# title: Conjecturing-Based Computational Discovery of Patterns in Data
# journal: None
# authors: J. P. Brooks, D. J. Edwards, C. E. Larson, N. Van Cleemput
# doi: None
# pdf_url: http://arxiv.org/pdf/2011.11576v3
# arxiv-id: 2008.00127v2
# published: 2020-07-31
# revised: 2022-10-14
# title: Dependence-robust confidence intervals for capture-recapture surveys
# journal: None
# authors: Jinghao Sun, Luk Van Baelen, Els Plettinckx, Forrest W. Crawford
# doi: None
# pdf_url: http://arxiv.org/pdf/2008.00127v2
# arxiv-id: 2205.11966v2
# published: 2022-05-24
# revised: 2022-10-11
# title: Benchmark Data and Evaluation Framework for Intent Discovery Around COVID-19 Vaccine Hesitancy
# journal: None
# authors: Shai Gretz, Assaf Toledo, Roni Friedman, Dan Lahav, Rose Weeks, Naor Bar-Zeev, João Sedoc, Pooja Sangha, Yoav Katz, Noam Slonim
# doi: None
# pdf_url: http://arxiv.org/pdf/2205.11966v2
# arxiv-id: 2210.04774v1
# published: 2022-10-10
# revised: 2022-10-10
# title: Online Resource Allocation with Samples
# journal: None
# authors: Negin Gorlezaei, Patrick Jaillet, Zijie Zhou
# doi: None
# pdf_url: http://arxiv.org/pdf/2210.04774v1
# arxiv-id: 2209.04431v2
# published: 2022-07-11
# revised: 2022-10-09
# title: Singular Secular Kuznets-like Period Realized Amid Industrial Transformation in US FDA Medical Devices: A Perspective on Innovation from 1976 to 2020
# journal: Expert Review of Medical Devices 2022
# authors: Iraj Daizadeh
# doi: 10.1080/17434440.2022.2139919
# pdf_url: http://arxiv.org/pdf/2209.04431v2
# arxiv-id: 2206.07375v2
# published: 2022-06-15
# revised: 2022-10-07
# title: Knowledge4COVID-19: A Semantic-based Approach for Constructing a COVID-19 related Knowledge Graph from Various Sources and Analysing Treatments' Toxicities
# journal: None
# authors: Ahmad Sakor, Samaneh Jozashoori, Emetis Niazmand, Ariam Rivas, Kostantinos Bougiatiotis, Fotis Aisopos, Enrique Iglesias, Philipp D. Rohde, Trupti Padiya, Anastasia Krithara, Georgios Paliouras, Maria-Esther Vidal
# doi: None
# pdf_url: http://arxiv.org/pdf/2206.07375v2
# arxiv-id: 2210.01882v1
# published: 2022-10-04
# revised: 2022-10-04
# title: A Collaborative Approach to the Analysis of the COVID-19 Response in Africa
# journal: None
# authors: Sharon Okwako, Irene Wanyana, Alice Namale, Betty Kivumbi Nannyonga, Sekou L. Remy, William Ogallo, Susan Kizito, Aisha Walcott-Bryant, Rhoda Wanyenze
# doi: None
# pdf_url: http://arxiv.org/pdf/2210.01882v1
# arxiv-id: 2209.13773v1
# published: 2022-09-28
# revised: 2022-09-28
# title: METS-CoV: A Dataset of Medical Entity and Targeted Sentiment on COVID-19 Related Tweets
# journal: None
# authors: Peilin Zhou, Zeqiang Wang, Dading Chong, Zhijiang Guo, Yining Hua, Zichang Su, Zhiyang Teng, Jiageng Wu, Jie Yang
# doi: None
# pdf_url: http://arxiv.org/pdf/2209.13773v1
# arxiv-id: 2110.15803v3
# published: 2021-10-19
# revised: 2022-09-26
# title: Natural Language Processing for Smart Healthcare
# journal: None
# authors: Binggui Zhou, Guanghua Yang, Zheng Shi, Shaodan Ma
# doi: None
# pdf_url: http://arxiv.org/pdf/2110.15803v3
# arxiv-id: 2209.11508v1
# published: 2022-09-23
# revised: 2022-09-23
# title: Biophysical Modeling of SARS-CoV-2 Assembly: Genome Condensation and Budding
# journal: Viruses 2022, 14, 2089
# authors: Siyu Li, Roya Zandi
# doi: 10.3390/v14102089
# pdf_url: http://arxiv.org/pdf/2209.11508v1
# arxiv-id: 2209.09810v1
# published: 2022-09-20
# revised: 2022-09-20
# title: The boosted HP filter is more general than you might think
# journal: None
# authors: Ziwei Mei, Peter C. B. Phillips, Zhentao Shi
# doi: None
# pdf_url: http://arxiv.org/pdf/2209.09810v1
# arxiv-id: 2209.05069v1
# published: 2022-09-12
# revised: 2022-09-12
# title: GPU-optimized Approaches to Molecular Docking-based Virtual Screening in Drug Discovery: A Comparative Analysis
# journal: None
# authors: Emanuele Vitali, Federico Ficarelli, Mauro Bisson, Davide Gadioli, Massimiliano Fatica, Andrea R. Beccari, Gianluca Palermo
# doi: None
# pdf_url: http://arxiv.org/pdf/2209.05069v1
# arxiv-id: 2003.00728v3
# published: 2020-03-02
# revised: 2022-09-03
# title: Prediction of Potential Commercially Available Inhibitors against SARS-CoV-2 by Multi-Task Deep Learning Model
# journal: Biomolecules. 2022; 12(8):1156
# authors: Fan Hu, Jiaxin Jiang, Peng Yin
# doi: 10.3390/biom12081156
# pdf_url: http://arxiv.org/pdf/2003.00728v3
# arxiv-id: 2209.00114v1
# published: 2022-08-31
# revised: 2022-08-31
# title: RAPTOR: Ravenous Throughput Computing
# journal: None
# authors: Andre Merzky, Matteo Turilli, Shantenu Jha
# doi: 10.1109/CCGrid54584.2022.00069
# pdf_url: http://arxiv.org/pdf/2209.00114v1
# arxiv-id: 2208.06362v3
# published: 2022-08-03
# revised: 2022-08-24
# title: Hybrid Approach to Identify Druglikeness Leading Compounds against COVID-19 3CL Protease
# journal: None
# authors: Imra Aqeel, Abdul Majid
# doi: 10.3390/ph15111333
# pdf_url: http://arxiv.org/pdf/2208.06362v3
# arxiv-id: 2208.06355v1
# published: 2022-08-12
# revised: 2022-08-12
# title: Communication network model of the immune system identifies the impact of interactions with SARS-CoV-2 proteins
# journal: None
# authors: Swarnavo Sarkar
# doi: None
# pdf_url: http://arxiv.org/pdf/2208.06355v1
# arxiv-id: 2208.05019v1
# published: 2022-08-09
# revised: 2022-08-09
# title: Automated Infectious Disease Forecasting: Use-cases and Practical Considerations for Pipeline Implementation
# journal: None
# authors: VP Nagraj, Chris Hulme-Lowe, Shakeel Jessa, Stephen D. Turner
# doi: None
# pdf_url: http://arxiv.org/pdf/2208.05019v1
# arxiv-id: 2206.01047v2
# published: 2022-06-02
# revised: 2022-07-26
# title: Drug Repurposing For SARS-COV-2 Using Molecular Docking
# journal: None
# authors: Imra Aqeel, Abdul Majid, Muhammad Ismail, Hina Bashir
# doi: None
# pdf_url: http://arxiv.org/pdf/2206.01047v2
# arxiv-id: 2206.14358v1
# published: 2022-06-29
# revised: 2022-06-29
# title: Using Twitter Data to Understand Public Perceptions of Approved versus Off-label Use for COVID-19-related Medications
# journal: amiajnl-2022-012337.R1
# authors: Yining Hua, Hang Jiang, Shixu Lin, Jie Yang, Joseph M. Plasek, David W. Bates, Li Zhou
# doi: 10.1093/jamia/ocac114
# pdf_url: http://arxiv.org/pdf/2206.14358v1
# arxiv-id: 2206.13634v1
# published: 2022-06-27
# revised: 2022-06-27
# title: Discrete Stochastic Optimization for Public Health Interventions with Constraints
# journal: None
# authors: Zewei Li, James C. Spall
# doi: None
# pdf_url: http://arxiv.org/pdf/2206.13634v1
# arxiv-id: 2206.06111v1
# published: 2022-06-10
# revised: 2022-06-10
# title: Extending Process Discovery with Model Complexity Optimization and Cyclic States Identification: Application to Healthcare Processes
# journal: None
# authors: Liubov O. Elkhovskaya, Alexander D. Kshenin, Marina A. Balakhontceva, Sergey V. Kovalchuk
# doi: None
# pdf_url: http://arxiv.org/pdf/2206.06111v1
# arxiv-id: 2110.11584v2
# published: 2021-10-22
# revised: 2022-06-10
# title: Multiwave COVID-19 Prediction from Social Awareness using Web Search and Mobility Data
# journal: None
# authors: J. Xue, T. Yabe, K. Tsubouchi, J. Ma, S. V. Ukkusuri
# doi: 10.1145/3534678.3539172
# pdf_url: http://arxiv.org/pdf/2110.11584v2
# arxiv-id: 2206.02970v1
# published: 2022-06-07
# revised: 2022-06-07
# title: Total Controllability Analysis Discovers Explainable Drugs for Covid-19 Therapy and Prevention
# journal: None
# authors: Xinru Wei, Chunyu Pan, Xizhe Zhang, Weixiong Zhang
# doi: None
# pdf_url: http://arxiv.org/pdf/2206.02970v1
# arxiv-id: 2204.09781v3
# published: 2022-04-20
# revised: 2022-06-03
# title: Multi-label classification for biomedical literature: an overview of the BioCreative VII LitCovid Track for COVID-19 literature topic annotations
# journal: None
# authors: Qingyu Chen, Alexis Allot, Robert Leaman, Rezarta Islamaj Doğan, Jingcheng Du, Li Fang, Kai Wang, Shuo Xu, Yuefu Zhang, Parsa Bagherzadeh, Sabine Bergler, Aakash Bhatnagar, Nidhir Bhavsar, Yung-Chun Chang, Sheng-Jie Lin, Wentai Tang, Hongtong Zhang, Ilija Tavchioski, Senja Pollak, Shubo Tian, Jinfeng Zhang, Yulia Otmakhova, Antonio Jimeno Yepes, Hang Dong, Honghan Wu, Richard Dufour, Yanis Labrak, Niladri Chatterjee, Kushagri Tandon, Fréjus Laleye, Loïc Rakotoson, Emmanuele Chersoni, Jinghang Gu, Annemarie Friedrich, Subhash Chandra Pujari, Mariia Chizhikova, Naveen Sivadasan, Naveen Sivadasan, Zhiyong Lu
# doi: None
# pdf_url: http://arxiv.org/pdf/2204.09781v3
# arxiv-id: 2205.14781v1
# published: 2022-05-29
# revised: 2022-05-29
# title: COVID-19 Literature Mining and Retrieval using Text Mining Approaches
# journal: None
# authors: Sanku Satya Uday, Satti Thanuja Pavani, T. Jaya Lakshmi, Rohit Chivukula
# doi: None
# pdf_url: http://arxiv.org/pdf/2205.14781v1
# arxiv-id: 2205.05618v1
# published: 2022-05-06
# revised: 2022-05-06
# title: A Mathematical Modeling Study of COVID-19 With Reference to Immigration from Urban to Rural Population
# journal: None
# authors: D. K. K. Vamsi, C. Bishal Chhetri, D. Bhanu Prakash, Seshasainath Ch., D. Surabhi Pandey
# doi: None
# pdf_url: http://arxiv.org/pdf/2205.05618v1
# arxiv-id: 2012.12263v3
# published: 2020-11-24
# revised: 2022-04-27
# title: Challenges of Equitable Vaccine Distribution in the COVID-19 Pandemic
# journal: None
# authors: Joseph Bae, Darshan Gandhi, Jil Kothari, Sheshank Shankar, Jonah Bae, Parth Patwa, Rohan Sukumaran, Aviral Chharia, Sanjay Adhikesaven, Shloak Rathod, Irene Nandutu, Sethuraman TV, Vanessa Yu, Krutika Misra, Srinidhi Murali, Aishwarya Saxena, Kasia Jakimowicz, Vivek Sharma, Rohan Iyer, Ashley Mehra, Alex Radunsky, Priyanshi Katiyar, Ananthu James, Jyoti Dalal, Sunaina Anand, Shailesh Advani, Jagjit Dhaliwal, Ramesh Raskar
# doi: None
# pdf_url: http://arxiv.org/pdf/2012.12263v3
# arxiv-id: 2110.07531v2
# published: 2021-10-14
# revised: 2022-04-22
# title: Deep learning models for predicting RNA degradation via dual crowdsourcing
# journal: None
# authors: Hannah K. Wayment-Steele, Wipapat Kladwang, Andrew M. Watkins, Do Soon Kim, Bojan Tunguz, Walter Reade, Maggie Demkin, Jonathan Romano, Roger Wellington-Oguri, John J. Nicol, Jiayang Gao, Kazuki Onodera, Kazuki Fujikawa, Hanfei Mao, Gilles Vandewiele, Michele Tinti, Bram Steenwinckel, Takuya Ito, Taiga Noumi, Shujun He, Keiichiro Ishi, Youhan Lee, Fatih Öztürk, Anthony Chiu, Emin Öztürk, Karim Amer, Mohamed Fares, Eterna Participants, Rhiju Das
# doi: None
# pdf_url: http://arxiv.org/pdf/2110.07531v2
# arxiv-id: 2204.09471v1
# published: 2022-04-20
# revised: 2022-04-20
# title: Mathematical artificial intelligence design of mutation-proof COVID-19 monoclonal antibodies
# journal: None
# authors: Jiahui Chen, Guo-Wei Wei
# doi: None
# pdf_url: http://arxiv.org/pdf/2204.09471v1
# arxiv-id: 2204.04017v1
# published: 2022-04-08
# revised: 2022-04-08
# title: Quantum Machine Learning Framework for Virtual Screening in Drug Discovery: a Prospective Quantum Advantage
# journal: None
# authors: Stefano Mensa, Emre Sahin, Francesco Tacchino, Panagiotis Kl. Barkoutsos, Ivano Tavernelli
# doi: None
# pdf_url: http://arxiv.org/pdf/2204.04017v1
# arxiv-id: 2201.00287v3
# published: 2022-01-02
# revised: 2022-04-07
# title: Drug repurposing for SARS-COV-2: A high-throughput molecular docking, molecular dynamics, machine learning, & ab-initio study
# journal: None
# authors: Jatin Kashyap, Dibakar Datta
# doi: 10.1007/s10853-022-07195-8
# pdf_url: http://arxiv.org/pdf/2201.00287v3
# arxiv-id: 2102.05470v5
# published: 2021-02-10
# revised: 2022-04-04
# title: The illicit trade of COVID-19 vaccines on the dark web
# journal: None
# authors: Alberto Bracci, Matthieu Nadini, Maxwell Aliapoulios, Damon McCoy, Ian Gray, Alexander Teytelboym, Angela Gallo, Andrea Baronchelli
# doi: None
# pdf_url: http://arxiv.org/pdf/2102.05470v5
# arxiv-id: 2203.10338v1
# published: 2022-03-19
# revised: 2022-03-19
# title: Understanding COVID-19 News Coverage using Medical NLP
# journal: None
# authors: Ali Emre Varol, Veysel Kocaman, Hasham Ul Haq, David Talby
# doi: None
# pdf_url: http://arxiv.org/pdf/2203.10338v1
# arxiv-id: 2004.10177v7
# published: 2020-04-21
# revised: 2022-03-17
# title: Algorithm for Optimized mRNA Design Improves Stability and Immunogenicity
# journal: None
# authors: He Zhang, Liang Zhang, Ang Lin, Congcong Xu, Ziyu Li, Kaibo Liu, Boxiang Liu, Xiaopin Ma, Fanfan Zhao, Weiguo Yao, Hangwen Li, David H. Mathews, Yujian Zhang, Liang Huang
# doi: None
# pdf_url: http://arxiv.org/pdf/2004.10177v7
# arxiv-id: 2202.05145v1
# published: 2022-02-08
# revised: 2022-02-08
# title: Deep learning for drug repurposing: methods, databases, and applications
# journal: None
# authors: Xiaoqin Pan, Xuan Lin, Dongsheng Cao, Xiangxiang Zeng, Philip S. Yu, Lifang He, Ruth Nussinov, Feixiong Cheng
# doi: None
# pdf_url: http://arxiv.org/pdf/2202.05145v1
# arxiv-id: 2202.01962v1
# published: 2022-02-04
# revised: 2022-02-04
# title: Population Calibration using Likelihood-Free Bayesian Inference
# journal: None
# authors: Christopher Drovandi, Brodie Lawson, Adrianne L Jenner, Alexander P Browning
# doi: None
# pdf_url: http://arxiv.org/pdf/2202.01962v1
# arxiv-id: 2009.10931v3
# published: 2020-09-23
# revised: 2022-02-01
# title: Drug repurposing for COVID-19 using graph neural network and harmonizing multiple evidence
# journal: Sci Rep 11, 23179 (2021)
# authors: Kanglin Hsieh, Yinyin Wang, Luyao Chen, Zhongming Zhao, Sean Savitz, Xiaoqian Jiang, Jing Tang, Yejin Kim
# doi: 10.1038/s41598-021-02353-5
# pdf_url: http://arxiv.org/pdf/2009.10931v3
# arxiv-id: 2202.00143v1
# published: 2022-01-31
# revised: 2022-01-31
# title: Gene set proximity analysis: expanding gene set enrichment analysis through learned geometric embeddings
# journal: None
# authors: Henry Cousins, Taryn Hall, Yinglong Guo, Luke Tso, Kathy Tzy-Hwa Tzeng, Le Cong, Russ Altman
# doi: None
# pdf_url: http://arxiv.org/pdf/2202.00143v1
# arxiv-id: 2201.12237v1
# published: 2022-01-28
# revised: 2022-01-28
# title: Experiences with managing data parallel computational workflows for High-throughput Fragment Molecular Orbital (FMO) Calculations
# journal: None
# authors: Dimuthu Wannipurage, Indrajit Deb, Eroma Abeysinghe, Sudhakar Pamidighantam, Suresh Marru, Marlon Pierce, Aaron T. Frank
# doi: None
# pdf_url: http://arxiv.org/pdf/2201.12237v1
# arxiv-id: 2201.08176v1
# published: 2022-01-20
# revised: 2022-01-20
# title: Insights from a computational analysis of the SARS-CoV-2 Omicron variant: Host-pathogen interaction, pathogenicity and possible therapeutics
# journal: Immunity, Inflammation and Disease 10 (2022), e639
# authors: Md Sorwer Alam Parvez, Manash Kumar Saha, Md. Ibrahim, Yusha Araf, Md. Taufiqul Islam, Gen Ohtsuki, Mohammad Jakir Hosen
# doi: 10.1002/iid3.639
# pdf_url: http://arxiv.org/pdf/2201.08176v1
# arxiv-id: 2108.13751v3
# published: 2021-08-31
# revised: 2022-01-19
# title: A Search Engine for Discovery of Scientific Challenges and Directions
# journal: AAAI 2022
# authors: Dan Lahav, Jon Saad Falcon, Bailey Kuehl, Sophie Johnson, Sravanthi Parasa, Noam Shomron, Duen Horng Chau, Diyi Yang, Eric Horvitz, Daniel S. Weld, Tom Hope
# doi: None
# pdf_url: http://arxiv.org/pdf/2108.13751v3
# arxiv-id: 2201.00237v1
# published: 2022-01-01
# revised: 2022-01-01
# title: Understanding Public Opinion on Using Hydroxychloroquine for COVID-19 Treatment via Social Media
# journal: None
# authors: Thuy T. Do, Du Nguyen, Anh Le, Anh Nguyen, Dong Nguyen, Nga Hoang, Uyen Le, Tuan Tran
# doi: None
# pdf_url: http://arxiv.org/pdf/2201.00237v1
# arxiv-id: 2112.02560v2
# published: 2021-12-05
# revised: 2021-12-21
# title: A comment-driven evidence appraisal approach for decision-making when only uncertain evidence available
# journal: None
# authors: Shuang Wang, Jian Du
# doi: None
# pdf_url: http://arxiv.org/pdf/2112.02560v2
# arxiv-id: 2112.01318v1
# published: 2021-12-01
# revised: 2021-12-01
# title: Omicron (B.1.1.529): Infectivity, vaccine breakthrough, and antibody resistance
# journal: None
# authors: Jiahui Chen, Rui Wang, Nancy Benovich Gilby, Guo-Wei Wei
# doi: None
# pdf_url: http://arxiv.org/pdf/2112.01318v1
# arxiv-id: 2109.06711v2
# published: 2021-09-14
# revised: 2021-11-29
# title: COVID-Net Clinical ICU: Enhanced Prediction of ICU Admission for COVID-19 Patients via Explainability and Trust Quantification
# journal: None
# authors: Audrey Chung, Mahmoud Famouri, Andrew Hryniowski, Alexander Wong
# doi: None
# pdf_url: http://arxiv.org/pdf/2109.06711v2
# arxiv-id: 2111.14480v1
# published: 2021-11-29
# revised: 2021-11-29
# title: MDistMult: A Multiple Scoring Functions Model for Link Prediction on Antiviral Drugs Knowledge Graph
# journal: None
# authors: Weichuan Wang, Zhiwen Xie, Jin Liu, Yucong Duan, Bo Huang, Junsheng Zhang
# doi: None
# pdf_url: http://arxiv.org/pdf/2111.14480v1
# arxiv-id: 2111.14283v1
# published: 2021-11-23
# revised: 2021-11-23
# title: Exploration of Dark Chemical Genomics Space via Portal Learning: Applied to Targeting the Undruggable Genome and COVID-19 Anti-Infective Polypharmacology
# journal: None
# authors: Tian Cai, Li Xie, Muge Chen, Yang Liu, Di He, Shuo Zhang, Cameron Mura, Philip E. Bourne, Lei Xie
# doi: None
# pdf_url: http://arxiv.org/pdf/2111.14283v1
# arxiv-id: 2111.11955v1
# published: 2021-11-23
# revised: 2021-11-23
# title: People Lie, Actions Don't! Modeling Infodemic Proliferation Predictors among Social Media Users
# journal: None
# authors: Chahat Raj, Priyanka Meel
# doi: None
# pdf_url: http://arxiv.org/pdf/2111.11955v1
# arxiv-id: 2110.13522v2
# published: 2021-10-26
# revised: 2021-10-30
# title: Probabilistic Entity Representation Model for Reasoning over Knowledge Graphs
# journal: None
# authors: Nurendra Choudhary, Nikhil Rao, Sumeet Katariya, Karthik Subbian, Chandan K. Reddy
# doi: None
# pdf_url: http://arxiv.org/pdf/2110.13522v2
# arxiv-id: 2110.13971v1
# published: 2021-10-26
# revised: 2021-10-26
# title: Diachronic Text Mining Investigation of Therapeutic Candidates for COVID-19
# journal: None
# authors: James Powell, Kari Sentz
# doi: None
# pdf_url: http://arxiv.org/pdf/2110.13971v1
# arxiv-id: 2110.12450v1
# published: 2021-10-24
# revised: 2021-10-24
# title: Pandemic model with data-driven phase detection, a study using COVID-19 data
# journal: None
# authors: Yuansan Liu, Saransh Srivastava, Zuo Huang, Felisa J. Vázquez-Abad
# doi: 10.1080/01605682.2021.1982652
# pdf_url: http://arxiv.org/pdf/2110.12450v1
# arxiv-id: 2110.09606v1
# published: 2021-10-18
# revised: 2021-10-18
# title: Efficient Analysis of COVID-19 Clinical Data using Machine Learning Models
# journal: None
# authors: Sarwan Ali, Yijing Zhou, Murray Patterson
# doi: None
# pdf_url: http://arxiv.org/pdf/2110.09606v1
# arxiv-id: 2110.06397v1
# published: 2021-10-12
# revised: 2021-10-12
# title: An Overview of Ontologies and Tool Support for COVID-19 Analytics
# journal: None
# authors: Aakash Ahmad, Madhushi Bandara, Mahdi Fahmideh, Henderik A. Proper, Giancarlo Guizzardi, Jeffrey Soar
# doi: None
# pdf_url: http://arxiv.org/pdf/2110.06397v1
# arxiv-id: 2005.07567v2
# published: 2020-05-15
# revised: 2021-10-05
# title: Accelerating drug repurposing for COVID-19 via modeling drug mechanism of action with large scale gene-expression profiles
# journal: None
# authors: Lu Han, G. C. Shan, B. F. Chu, H. Y. Wang, Z. J. Wang, S. Q. Gao, W. X. Zhou
# doi: None
# pdf_url: http://arxiv.org/pdf/2005.07567v2
# arxiv-id: 2109.13739v2
# published: 2021-08-18
# revised: 2021-10-01
# title: Bayesian hypothesis testing and hierarchical modelling of ivermectin effectiveness in treating Covid-19
# journal: None
# authors: Martin Neil, Norman Fenton
# doi: None
# pdf_url: http://arxiv.org/pdf/2109.13739v2
# arxiv-id: 2109.03565v2
# published: 2021-09-08
# revised: 2021-09-22
# title: In silico drug repositioning for COVID-19 using absolute binding free energy calculations
# journal: None
# authors: Théau Debroise, Rose Hoste, Quentin Chamayou, Hervé Minoux, Bruno Filoche-Rommé, Marc Bianciotto, Jean-Philippe Rameau, Laurent Schio, Maximilien Levesque
# doi: None
# pdf_url: http://arxiv.org/pdf/2109.03565v2
# arxiv-id: 2106.13375v2
# published: 2021-06-25
# revised: 2021-09-16
# title: Domain-Specific Pretraining for Vertical Search: Case Study on Biomedical Literature
# journal: None
# authors: Yu Wang, Jinchao Li, Tristan Naumann, Chenyan Xiong, Hao Cheng, Robert Tinn, Cliff Wong, Naoto Usuyama, Richard Rogahn, Zhihong Shen, Yang Qin, Eric Horvitz, Paul N. Bennett, Jianfeng Gao, Hoifung Poon
# doi: 10.1145/3447548.3469053
# pdf_url: http://arxiv.org/pdf/2106.13375v2
# arxiv-id: 2103.02723v3
# published: 2021-03-03
# revised: 2021-09-10
# title: Identification and Development of Therapeutics for COVID-19
# journal: None
# authors: Halie M. Rando, Nils Wellhausen, Soumita Ghosh, Alexandra J. Lee, Anna Ada Dattoli, Fengling Hu, James Brian Byrd, Diane N. Rafizadeh, Ronan Lordan, Yanjun Qi, Yuchen Sun, Christian Brueffer, Jeffrey M. Field, Marouen Ben Guebila, Nafisa M. Jadavji, Ashwin N. Skelly, Bharath Ramsundar, Jinhui Wang, Rishi Raj Goel, YoSon Park, the COVID-19 Review Consortium, Simina M. Boca, Anthony Gitter, Casey S. Greene
# doi: 10.1128/mSystems.00233-21
# pdf_url: http://arxiv.org/pdf/2103.02723v3
# arxiv-id: 2109.00100v4
# published: 2021-08-31
# revised: 2021-09-07
# title: Proceedings of KDD 2021 Workshop on Data-driven Humanitarian Mapping: Harnessing Human-Machine Intelligence for High-Stake Public Policy and Resilience Planning
# journal: None
# authors: Snehalkumar, S. Gaikwad, Shankar Iyer, Dalton Lunga, Elizabeth Bondi
# doi: None
# pdf_url: http://arxiv.org/pdf/2109.00100v4
# arxiv-id: 2109.00435v3
# published: 2021-09-01
# revised: 2021-09-07
# title: Proceedings of KDD 2020 Workshop on Data-driven Humanitarian Mapping: Harnessing Human-Machine Intelligence for High-Stake Public Policy and Resilience Planning
# journal: None
# authors: Snehalkumar, S. Gaikwad, Shankar Iyer, Dalton Lunga, Yu-Ru Lin
# doi: None
# pdf_url: http://arxiv.org/pdf/2109.00435v3
# arxiv-id: 2010.16413v3
# published: 2020-10-09
# revised: 2021-09-05
# title: Artificial Intelligence (AI) in Action: Addressing the COVID-19 Pandemic with Natural Language Processing (NLP)
# journal: Annual Review of Biomedical Data Science 4 (2021)
# authors: Qingyu Chen, Robert Leaman, Alexis Allot, Ling Luo, Chih-Hsuan Wei, Shankai Yan, Zhiyong Lu
# doi: 10.1146/annurev-biodatasci-021821-061045
# pdf_url: http://arxiv.org/pdf/2010.16413v3
# arxiv-id: 2103.02843v2
# published: 2021-03-04
# revised: 2021-09-04
# title: Pandemic Drugs at Pandemic Speed: Infrastructure for Accelerating COVID-19 Drug Discovery with Hybrid Machine Learning- and Physics-based Simulations on High Performance Computers
# journal: Interface Focus. 2021. 11 (6): 20210018
# authors: Agastya P. Bhati, Shunzhou Wan, Dario Alfè, Austin R. Clyde, Mathis Bode, Li Tan, Mikhail Titov, Andre Merzky, Matteo Turilli, Shantenu Jha, Roger R. Highfield, Walter Rocchia, Nicola Scafuri, Sauro Succi, Dieter Kranzlmüller, Gerald Mathias, David Wifling, Yann Donon, Alberto Di Meglio, Sofia Vallecorsa, Heng Ma, Anda Trifan, Arvind Ramanathan, Tom Brettin, Alexander Partin, Fangfang Xia, Xiaotan Duan, Rick Stevens, Peter V. Coveney
# doi: 10.1098/rsfs.2021.0018
# pdf_url: http://arxiv.org/pdf/2103.02843v2
# arxiv-id: 2108.13764v1
# published: 2021-08-31
# revised: 2021-08-31
# title: Virtual screening of Microalgal compounds as potential inhibitors of Type 2 Human Transmembrane serine protease (TMPRSS2)
# journal: None
# authors: Ibrahim Mohammed
# doi: None
# pdf_url: http://arxiv.org/pdf/2108.13764v1
# arxiv-id: 2108.12150v1
# published: 2021-08-27
# revised: 2021-08-27
# title: A Nested Multi-Scale Model for COVID-19 Viral Infection
# journal: None
# authors: Bishal Chhetri, D. K. K Vamsi, Carani Sanjeevi
# doi: None
# pdf_url: http://arxiv.org/pdf/2108.12150v1
# arxiv-id: 2107.05347v2
# published: 2021-07-09
# revised: 2021-08-24
# title: Seasonal and Secular Periodicities Identified in the Dynamics of US FDA Medical Devices (1976 2020) Portends Intrinsic Industrial Transformation and Independence of Certain Crises
# journal: None
# authors: Iraj Daizadeh
# doi: 10.1007/s43441-021-00334-4
# pdf_url: http://arxiv.org/pdf/2107.05347v2
# arxiv-id: 2108.09739v1
# published: 2021-08-22
# revised: 2021-08-22
# title: Exploring Multi-Dimensional Events Characterizing Tech Start-Up Emergence in the Nigerian Entrepreneurial Ecosystem
# journal: None
# authors: Emanuel Okoro Ajah, Chidi Ononiwu
# doi: None
# pdf_url: http://arxiv.org/pdf/2108.09739v1
# arxiv-id: 2108.07046v2
# published: 2021-08-16
# revised: 2021-08-19
# title: WiseR: An end-to-end structure learning and deployment framework for causal graphical models
# journal: None
# authors: Shubham Maheshwari, Khushbu Pahwa, Tavpritesh Sethi
# doi: None
# pdf_url: http://arxiv.org/pdf/2108.07046v2
# arxiv-id: 2108.06473v1
# published: 2021-08-14
# revised: 2021-08-14
# title: Evidence Aggregation for Treatment Choice
# journal: None
# authors: Takuya Ishihara, Toru Kitagawa
# doi: None
# pdf_url: http://arxiv.org/pdf/2108.06473v1
# arxiv-id: 2104.09394v2
# published: 2021-04-19
# revised: 2021-08-05
# title: Remote teaching data-driven physical modeling through a COVID-19 open ended data challenge
# journal: None
# authors: Marco Cosentino Lagomarsino, Guglielmo Pacifico, Valerio Firmano, Edoardo Bella, Pietro Benzoni, Jacopo Grilli, Federico Bassetti, Fabrizio Capuani, Pietro Cicuta, Marco Gherardi
# doi: 10.1088/1361-6404/ac79e1
# pdf_url: http://arxiv.org/pdf/2104.09394v2
# arxiv-id: 2104.12556v3
# published: 2021-04-16
# revised: 2021-08-04
# title: COVID-19 Modeling: A Review
# journal: None
# authors: Longbing Cao, Qing Liu
# doi: None
# pdf_url: http://arxiv.org/pdf/2104.12556v3
# arxiv-id: 2108.00664v1
# published: 2021-08-02
# revised: 2021-08-02
# title: Learning who is in the market from time series: market participant discovery through adversarial calibration of multi-agent simulators
# journal: None
# authors: Victor Storchan, Svitlana Vyetrenko, Tucker Balch
# doi: None
# pdf_url: http://arxiv.org/pdf/2108.00664v1
# arxiv-id: 2107.12799v1
# published: 2021-07-27
# revised: 2021-07-27
# title: New Candidates for Furin Inhibition as Probable Treat for COVID-19: Docking Output
# journal: None
# authors: Mohammad Reza Dayer
# doi: None
# pdf_url: http://arxiv.org/pdf/2107.12799v1
# arxiv-id: 2107.12463v1
# published: 2021-07-26
# revised: 2021-07-26
# title: Sample Preparation Meets Farey Sequence: A New Design Technique for Free-Flowing Microfluidic Networks
# journal: None
# authors: Tapalina Banerjee, Sudip Poddar, Tsung-Yi Ho, Bhargab B. Bhattacharya
# doi: None
# pdf_url: http://arxiv.org/pdf/2107.12463v1
# arxiv-id: 2107.09217v1
# published: 2021-07-20
# revised: 2021-07-20
# title: Heterogeneous network-based drug repurposing for COVID-19
# journal: None
# authors: Shuting Jin, Xiangxiang Zeng, Wei Huang, Feng Xia, Changzhi Jiang, Xiangrong Liu, Shaoliang Peng
# doi: None
# pdf_url: http://arxiv.org/pdf/2107.09217v1
# arxiv-id: 2107.09602v1
# published: 2021-07-13
# revised: 2021-07-13
# title: Medical Imaging with Deep Learning for COVID- 19 Diagnosis: A Comprehensive Review
# journal: International Journal of Computer Information Systems and
#   Industrial Management Applications(ISSN 2150-7988), Volume 13, 2021
# authors: Subrato Bharati, Prajoy Podder, M. Rubaiyat Hossain Mondal, V. B. Surya Prasath
# doi: None
# pdf_url: http://arxiv.org/pdf/2107.09602v1
# arxiv-id: 2012.01981v3
# published: 2020-12-02
# revised: 2021-07-06
# title: Advanced Graph and Sequence Neural Networks for Molecular Property Prediction and Drug Discovery
# journal: None
# authors: Zhengyang Wang, Meng Liu, Youzhi Luo, Zhao Xu, Yaochen Xie, Limei Wang, Lei Cai, Qi Qi, Zhuoning Yuan, Tianbao Yang, Shuiwang Ji
# doi: None
# pdf_url: http://arxiv.org/pdf/2012.01981v3
# arxiv-id: 2106.14631v1
# published: 2021-06-28
# revised: 2021-06-28
# title: Blockchain and AI-based Solutions to Combat Coronavirus (COVID-19)-like Epidemics: A Survey
# journal: None
# authors: Dinh C. Nguyen, Ming Ding, Pubudu N. Pathirana, Aruna Seneviratne
# doi: 10.1109/ACCESS.2021.3093633
# pdf_url: http://arxiv.org/pdf/2106.14631v1
# arxiv-id: 2106.12297v1
# published: 2021-06-23
# revised: 2021-06-23
# title: Network analytics for drug repurposing in COVID-19
# journal: None
# authors: Nicoleta Siminea, Victor Popescu, Jose Angel Sanchez Martin, Daniela Florea, Georgiana Gavril, Ana-Maria Gheorghe, Corina Itcus, Krishna Kanhaiya, Octavian Pacioglu, Laura Ioana Popa, Romica Trandafir, Maria Iris Tusa, Manuela Sidoroff, Mihaela Paun, Eugen Czeizler, Andrei Paun, Ion Petre
# doi: None
# pdf_url: http://arxiv.org/pdf/2106.12297v1
# arxiv-id: 2102.09507v4
# published: 2021-02-18
# revised: 2021-06-21
# title: Regular Expressions for Fast-response COVID-19 Text Classification
# journal: None
# authors: Igor L. Markov, Jacqueline Liu, Adam Vagner
# doi: None
# pdf_url: http://arxiv.org/pdf/2102.09507v4
# arxiv-id: 2106.06911v1
# published: 2021-06-13
# revised: 2021-06-13
# title: An Interaction-based Convolutional Neural Network (ICNN) Towards Better Understanding of COVID-19 X-ray Images
# journal: Algorithms 2021
# authors: Shaw-Hwa Lo, Yiqiao Yin
# doi: 10.3390/a14110337
# pdf_url: http://arxiv.org/pdf/2106.06911v1
# arxiv-id: 2106.05440v1
# published: 2021-06-10
# revised: 2021-06-10
# title: In silico Prediction of Mozenavir as potential drug for SARS-CoV-2 infection via Binding Multiple Drug Targets
# journal: None
# authors: Estari Mamidalaa, Rakesh Davella, Swapna Gurrapu, Munipally Praveen Kumar, Abhiav
# doi: None
# pdf_url: http://arxiv.org/pdf/2106.05440v1
# arxiv-id: 2104.01533v2
# published: 2021-04-04
# revised: 2021-06-06
# title: Unexpected novel Merbecovirus discoveries in agricultural sequencing datasets from Wuhan, China
# journal: None
# authors: Daoyu Zhang, Adrian Jones, Yuri Deigin, Karl Sirotkin, Alejandro Sousa
# doi: None
# pdf_url: http://arxiv.org/pdf/2104.01533v2
# arxiv-id: 2104.14005v3
# published: 2021-04-28
# revised: 2021-06-04
# title: Unlocking capacities of viral genomics for the COVID-19 pandemic response
# journal: None
# authors: Sergey Knyazev, Karishma Chhugani, Varuni Sarwal, Ram Ayyala, Harman Singh, Smruthi Karthikeyan, Dhrithi Deshpande, Zoia Comarova, Angela Lu, Yuri Porozov, Aiping Wu, Malak Abedalthagafi, Shivashankar Nagaraj, Adam Smith, Pavel Skums, Jason Ladner, Tommy Tsan-Yuk Lam, Nicholas Wu, Alex Zelikovsky, Rob Knight, Keith Crandall, Serghei Mangul
# doi: None
# pdf_url: http://arxiv.org/pdf/2104.14005v3
# arxiv-id: 2106.00356v1
# published: 2021-06-01
# revised: 2021-06-01
# title: Predicting COVID-19 Spread from Large-Scale Mobility Data
# journal: None
# authors: Amray Schwabe, Joel Persson, Stefan Feuerriegel
# doi: None
# pdf_url: http://arxiv.org/pdf/2106.00356v1
# arxiv-id: 2105.14433v1
# published: 2021-05-30
# revised: 2021-05-30
# title: Time Optimal Control Studies on COVID-19 Incorporating Adverse Events of the Antiviral Drugs
# journal: None
# authors: Bishal Chhetri, Vijay M. Bhagat, Swapna Muthusamy, Ananth V S, D. K. K. Vamsi, Carani B Sanjeevi
# doi: None
# pdf_url: http://arxiv.org/pdf/2105.14433v1
# arxiv-id: 2105.14333v1
# published: 2021-05-29
# revised: 2021-05-29
# title: Covid-19 diagnosis from x-ray using neural networks
# journal: None
# authors: Dinesh J, Mohammed Rhithick A
# doi: None
# pdf_url: http://arxiv.org/pdf/2105.14333v1
# arxiv-id: 2105.12267v1
# published: 2021-05-26
# revised: 2021-05-26
# title: Effects of COVID-19 Vaccine Developments and Rollout on the Capital Market -- A Case Study
# journal: None
# authors: Maximilian Vierlboeck, Roshanak Rose Nilchiani
# doi: None
# pdf_url: http://arxiv.org/pdf/2105.12267v1
# arxiv-id: 2105.11410v1
# published: 2021-05-24
# revised: 2021-05-24
# title: From Base Data To Knowledge Discovery -- A Life Cycle Approach -- Using Multilayer Networks
# journal: None
# authors: Abhishek Santra, Kanthi Komar, Sanjukta Bhowmick, Sharma Chakravarthy
# doi: None
# pdf_url: http://arxiv.org/pdf/2105.11410v1
# arxiv-id: 2010.04700v3
# published: 2020-10-09
# revised: 2021-05-18
# title: Distributed Computing in a Pandemic: A Review of Technologies Available for Tackling COVID-19
# journal: ADCAIJ: Advances in Distributed Computing and Artificial
#   Intelligence Journal, 11(1), 9-43 (2022)
# authors: Jamie J Alnasir
# doi: 10.14201/adcaij.27337
# pdf_url: http://arxiv.org/pdf/2010.04700v3
# arxiv-id: 2008.11308v2
# published: 2020-08-25
# revised: 2021-05-18
# title: Identifying Coordinated Accounts on Social Media through Hidden Influence and Group Behaviours
# journal: ACM SIGKDD International Conference on Knowledge Discovery & Data
#   Mining 2021
# authors: Karishma Sharma, Yizhou Zhang, Emilio Ferrara, Yan Liu
# doi: None
# pdf_url: http://arxiv.org/pdf/2008.11308v2
# arxiv-id: 2007.00576v6
# published: 2020-07-01
# revised: 2021-05-12
# title: COVID-19 Literature Knowledge Graph Construction and Drug Repurposing Report Generation
# journal: None
# authors: Qingyun Wang, Manling Li, Xuan Wang, Nikolaus Parulian, Guangxing Han, Jiawei Ma, Jingxuan Tu, Ying Lin, Haoran Zhang, Weili Liu, Aabhas Chauhan, Yingjun Guan, Bangzheng Li, Ruisong Li, Xiangchen Song, Yi R. Fung, Heng Ji, Jiawei Han, Shih-Fu Chang, James Pustejovsky, Jasmine Rah, David Liem, Ahmed Elsayed, Martha Palmer, Clare Voss, Cynthia Schneider, Boyan Onyshkevych
# doi: None
# pdf_url: http://arxiv.org/pdf/2007.00576v6
# arxiv-id: 2105.05220v1
# published: 2021-05-11
# revised: 2021-05-11
# title: Retro Drug Design: From Target Properties to Molecular Structures
# journal: None
# authors: Yuhong Wang, Sam Michael, Ruili Huang, Jinghua Zhao, Katlin Recabo, Danielle Bougie, Qiang Shu, Paul Shinn, Hongmao Sun
# doi: None
# pdf_url: http://arxiv.org/pdf/2105.05220v1
# arxiv-id: 2105.10489v1
# published: 2021-05-07
# revised: 2021-05-07
# title: Evening the Score: Targeting SARS-CoV-2 Protease Inhibition in Graph Generative Models for Therapeutic Candidates
# journal: Published at ICLR 2021 Workshop on Machine Learning for Preventing
#   and Combating Pandemics
# authors: Jenna Bilbrey, Logan Ward, Sutanay Choudhury, Neeraj Kumar, Ganesh Sivaraman
# doi: None
# pdf_url: http://arxiv.org/pdf/2105.10489v1
# arxiv-id: 2006.03146v3
# published: 2020-06-04
# revised: 2021-05-03
# title: Analyzing the State of COVID-19: Real-time Visual Data Analysis, Short-Term Forecasting, and Risk Factor Identification
# journal: None
# authors: Jiawei Long
# doi: None
# pdf_url: http://arxiv.org/pdf/2006.03146v3
# arxiv-id: 2104.13224v1
# published: 2021-04-25
# revised: 2021-04-25
# title: Preventing and Controlling Epidemics through Blockchain-Assisted AI-Enabled Networks
# journal: None
# authors: Safa Otoum, Ismaeel Al Ridhawi, Hussein T. Mouftah
# doi: None
# pdf_url: http://arxiv.org/pdf/2104.13224v1
# arxiv-id: 2104.12003v1
# published: 2021-04-24
# revised: 2021-04-24
# title: A Birds-eye (Re)View of Acid-suppression Drugs, COVID-19, and the Highly Variable Literature
# journal: None
# authors: Cameron Mura, Saskia Preissner, Robert Preissner, Philip E. Bourne
# doi: None
# pdf_url: http://arxiv.org/pdf/2104.12003v1
# arxiv-id: 2104.11674v1
# published: 2021-04-23
# revised: 2021-04-23
# title: Genetic Constrained Graph Variational Autoencoder for COVID-19 Drug Discovery
# journal: None
# authors: Tianyue Cheng, Tianchi Fan, Landi Wang
# doi: None
# pdf_url: http://arxiv.org/pdf/2104.11674v1
# arxiv-id: 2103.15561v2
# published: 2021-03-24
# revised: 2021-04-21
# title: Pyfectious: An individual-level simulator to discover optimal containment polices for epidemic diseases
# journal: None
# authors: Arash Mehrjou, Ashkan Soleymani, Amin Abyaneh, Samir Bhatt, Bernhard Schölkopf, Stefan Bauer
# doi: None
# pdf_url: http://arxiv.org/pdf/2103.15561v2
# arxiv-id: 2104.08867v1
# published: 2021-04-18
# revised: 2021-04-18
# title: User Behavior Discovery in the COVID-19 Era through the Sentiment Analysis of User Tweet Texts
# journal: None
# authors: Amin Mahmoudi, Victoria Wai-lan Yeung, Eric W. K. See-To
# doi: None
# pdf_url: http://arxiv.org/pdf/2104.08867v1
# arxiv-id: 2104.07367v1
# published: 2021-04-15
# revised: 2021-04-15
# title: BERT based Transformers lead the way in Extraction of Health Information from Social Media
# journal: None
# authors: Sidharth R, Abhiraj Tiwari, Parthivi Choubey, Saisha Kashyap, Sahil Khose, Kumud Lakara, Nishesh Singh, Ujjwal Verma
# doi: None
# pdf_url: http://arxiv.org/pdf/2104.07367v1
# arxiv-id: 2104.05321v1
# published: 2021-04-12
# revised: 2021-04-12
# title: Combining exogenous and endogenous signals with a semi-supervised co-attention network for early detection of COVID-19 fake tweets
# journal: None
# authors: Rachit Bansal, William Scott Paka, Nidhi, Shubhashis Sengupta, Tanmoy Chakraborty
# doi: None
# pdf_url: http://arxiv.org/pdf/2104.05321v1
# arxiv-id: 2104.05188v1
# published: 2021-04-12
# revised: 2021-04-12
# title: Accelerating science with human versus alien artificial intelligences
# journal: None
# authors: Jamshid Sourati, James Evans
# doi: None
# pdf_url: http://arxiv.org/pdf/2104.05188v1
# arxiv-id: 2104.01113v2
# published: 2021-03-24
# revised: 2021-04-05
# title: Drug Recommendation System based on Sentiment Analysis of Drug Reviews using Machine Learning
# journal: None
# authors: Satvik Garg
# doi: 10.1109/Confluence51648.2021.9377188
# pdf_url: http://arxiv.org/pdf/2104.01113v2
# arxiv-id: 2103.16192v1
# published: 2021-03-30
# revised: 2021-03-30
# title: Selection of an engineering institution: Students perceptions of choice characteristics and suitability under the COVID-19 pandemic
# journal: None
# authors: Prashant Mahajan
# doi: 10.20944/preprints202103.0665.v1
# pdf_url: http://arxiv.org/pdf/2103.16192v1
# arxiv-id: 2008.04172v4
# published: 2020-08-10
# revised: 2021-03-29
# title: A single-cell mathematical model of SARS-CoV-2 induced pyroptosis and the effects of anti-inflammatory intervention
# journal: None
# authors: Sara J Hamis, Fiona R Macfarlane
# doi: None
# pdf_url: http://arxiv.org/pdf/2008.04172v4
# arxiv-id: 2103.14102v1
# published: 2021-03-25
# revised: 2021-03-25
# title: Crime and COVID-19 in Rio de Janeiro: How does organized crime shape the disease evolution?
# journal: International Journal of Modern Physics C 32, 2150122 (2021)
# authors: Nuno Crokidakis, Lucas Sigaud
# doi: 10.1142/S0129183121501229
# pdf_url: http://arxiv.org/pdf/2103.14102v1
# arxiv-id: 2103.13844v1
# published: 2021-03-25
# revised: 2021-03-25
# title: DCcov: Repositioning of Drugs and Drug Combinations for SARS-CoV-2 Infected Lung through Constraint-Based Modelling
# journal: None
# authors: Ali Kishk, Maria Pires Pacheco, Thomas Sauter
# doi: 10.1016/j.isci.2021.103331
# pdf_url: http://arxiv.org/pdf/2103.13844v1
# arxiv-id: 2103.13297v1
# published: 2021-03-23
# revised: 2021-03-23
# title: Making it normal for new enrollments: Effect of institutional and pandemic influence on selecting an engineering institution under the COVID-19 pandemic situation
# journal: None
# authors: Prashant Mahajan, Vaishali Patil
# doi: 10.21203/rs.3.rs-354086/v1
# pdf_url: http://arxiv.org/pdf/2103.13297v1
# arxiv-id: 2006.03354v2
# published: 2020-06-05
# revised: 2021-03-11
# title: Classification Aware Neural Topic Model and its Application on a New COVID-19 Disinformation Corpus
# journal: PLOS ONE 2021
# authors: Xingyi Song, Johann Petrak, Ye Jiang, Iknoor Singh, Diana Maynard, Kalina Bontcheva
# doi: 10.1371/journal.pone.0247086
# pdf_url: http://arxiv.org/pdf/2006.03354v2
# arxiv-id: 2103.06578v1
# published: 2021-03-11
# revised: 2021-03-11
# title: Quantitative Interpretations of Energetic Features and Key Residues at SARS Coronavirus Spike Receptor-Binding Domain and ACE2 Receptor Interface
# journal: Nanoscale, 2021
# authors: Yanmei Yang, Yunju Zhang, Yuanyuan Qu, Xuewei Liu, Mingwen Zhao, Yuguang Mu, Weifeng Li
# doi: 10.1039/D1NR01672E
# pdf_url: http://arxiv.org/pdf/2103.06578v1
# arxiv-id: 2007.02202v2
# published: 2020-07-04
# revised: 2021-03-11
# title: A Survey on Applications of Artificial Intelligence in Fighting Against COVID-19
# journal: None
# authors: Jianguo Chen, Kenli Li, Zhaolei Zhang, Keqin Li, Philip S. Yu
# doi: None
# pdf_url: http://arxiv.org/pdf/2007.02202v2
# arxiv-id: 2010.06357v2
# published: 2020-10-13
# revised: 2021-03-09
# title: Prediction and mitigation of mutation threats to COVID-19 vaccines and antibody therapies
# journal: None
# authors: Jiahui Chen, Kaifu Gao, Rui Wang, Guowei Wei
# doi: None
# pdf_url: http://arxiv.org/pdf/2010.06357v2
# arxiv-id: 2007.10445v2
# published: 2020-07-20
# revised: 2021-03-04
# title: PanRep: Graph neural networks for extracting universal node embeddings in heterogeneous graphs
# journal: None
# authors: Vassilis N. Ioannidis, Da Zheng, George Karypis
# doi: None
# pdf_url: http://arxiv.org/pdf/2007.10445v2
# arxiv-id: 2103.01896v1
# published: 2021-03-02
# revised: 2021-03-02
# title: An Earth-mass Planet in a Time of Covid-19: KMT-2020-BLG-0414Lb
# journal: None
# authors: Weicheng Zang, Cheongho Han, Iona Kondo, Jennifer C. Yee, Chung-Uk Lee, Andrew Gould, Shude Mao, Leandro de Almeida, Yossi Shvartzvald, Xiangyu Zhang, Michael D. Albrow, Sun-Ju Chung, Kyu-Ha Hwang, Youn Kil Jung, Yoon-Hyun Ryu, In-Gu Shin, Sang-Mok Cha, Dong-Jin Kim, Hyoun-Woo Kim, Seung-Lee Kim, Dong-Joo Lee, Yongseok Lee, Byeong-Gon Park, Richard W. Pogge, John Drummond, Thiam-Guan Tan, José Dias do Nascimento Júnior, Dan Maoz, Matthew T. Penny, Wei Zhu, Ian A. Bond, Fumio Abe, Richard Barry, David P. Bennett, Aparna Bhattacharya, Martin Donachie, Hirosane Fujii, Akihiko Fukui, Yuki Hirao, Yoshitaka Itow, Rintaro Kirikawa, Naoki Koshimoto, Man Cheung Alex Li, Yutaka Matsubara, Yasushi Muraki, Shota Miyazaki, Clément Ranc, Nicholas J. Rattenbury, Yuki Satoh, Hikaru Shoji, Takahiro Sumi, Daisuke Suzuki, Yuzuru Tanaka, Paul J. Tristram, Tsubasa Yamawaki, Atsunori Yonehara, Andreea Petric, Todd Burdullis, Pascal Fouqué
# doi: 10.1088/1674-4527/21/9/239
# pdf_url: http://arxiv.org/pdf/2103.01896v1
# arxiv-id: 2102.13103v1
# published: 2021-02-24
# revised: 2021-02-24
# title: Estimating Vaccine Efficacy Over Time After a Randomized Study is Unblinded
# journal: None
# authors: Anastasios A. Tsiatis, Marie Davidian
# doi: None
# pdf_url: http://arxiv.org/pdf/2102.13103v1
# arxiv-id: 2102.08628v1
# published: 2021-02-17
# revised: 2021-02-17
# title: Knowledge discovery from emergency ambulance dispatch during COVID-19: A case study of Nagoya City, Japan
# journal: Journal of Biomedical Informatics, 2021
# authors: Essam A. Rashed, Sachiko Kodera, Hidenobu Shirakami, Ryotetsu Kawaguchi, Kazuhiro Watanabe, Akimasa Hirata
# doi: 10.1016/j.jbi.2021.103743
# pdf_url: http://arxiv.org/pdf/2102.08628v1
# arxiv-id: 2102.07610v1
# published: 2021-02-15
# revised: 2021-02-15
# title: Application of Quantitative Systems Pharmacology to guide the optimal dosing of COVID-19 vaccines
# journal: CPT: Pharmacometrics and Systems Pharmacology, 2021
# authors: Mario Giorgi, Rajat Desikan, Piet H. van der Graaf, Andrzej M. Kierzek
# doi: 10.1002/psp4.12700
# pdf_url: http://arxiv.org/pdf/2102.07610v1
# arxiv-id: 2102.07022v1
# published: 2021-02-13
# revised: 2021-02-13
# title: Towards reliable and transparent vaccine phase III trials with smart contracts
# journal: None
# authors: Ivan da Silva Sendin, Rodrigo Sanches Miani
# doi: None
# pdf_url: http://arxiv.org/pdf/2102.07022v1
# arxiv-id: 2102.04977v1
# published: 2021-02-09
# revised: 2021-02-09
# title: Benchmarking Deep Graph Generative Models for Optimizing New Drug Molecules for COVID-19
# journal: None
# authors: Logan Ward, Jenna A. Bilbrey, Sutanay Choudhury, Neeraj Kumar, Ganesh Sivaraman
# doi: None
# pdf_url: http://arxiv.org/pdf/2102.04977v1
# arxiv-id: 2010.09600v2
# published: 2020-10-19
# revised: 2021-02-05
# title: Drug Repurposing for COVID-19 via Knowledge Graph Completion
# journal: None
# authors: Rui Zhang, Dimitar Hristovski, Dalton Schutte, Andrej Kastrin, Marcelo Fiszman, Halil Kilicoglu
# doi: 10.1016/j.jbi.2021.103696
# pdf_url: http://arxiv.org/pdf/2010.09600v2
# arxiv-id: 2102.02250v1
# published: 2021-02-03
# revised: 2021-02-03
# title: Dietary Supplements and Nutraceuticals Under Investigation for COVID-19 Prevention and Treatment
# journal: None
# authors: Ronan Lordan, Halie M. Rando, COVID-19 Review Consortium, Casey S. Greene
# doi: 10.1128/mSystems.00122-21
# pdf_url: http://arxiv.org/pdf/2102.02250v1
# arxiv-id: 2102.00971v1
# published: 2021-02-01
# revised: 2021-02-01
# title: Methodology-centered review of molecular modeling, simulation, and prediction of SARS-CoV-2
# journal: None
# authors: Kaifu Gao, Rui Wang, Jiahui Chen, Limei Cheng, Jaclyn Frishcosy, Yuta Huzumi, Yuchi Qiu, Tom Schluckbier, Guo-Wei Wei
# doi: None
# pdf_url: http://arxiv.org/pdf/2102.00971v1
# arxiv-id: 2102.00197v1
# published: 2021-01-30
# revised: 2021-01-30
# title: Rapid detection of fast innovation under the pressure of COVID-19
# journal: PLOS ONE (2020) 15(12): e0244175
# authors: Nicola Melluso, Andrea Bonaccorsi, Filippo Chiarello, Gualtiero Fantoni
# doi: 10.1371/journal.pone.0244175
# pdf_url: http://arxiv.org/pdf/2102.00197v1
# arxiv-id: 2101.12547v1
# published: 2021-01-29
# revised: 2021-01-29
# title: BridgeDPI: A Novel Graph Neural Network for Predicting Drug-Protein Interactions
# journal: None
# authors: Yifan Wu, Min Gao, Min Zeng, Feiyang Chen, Min Li, Jie Zhang
# doi: None
# pdf_url: http://arxiv.org/pdf/2101.12547v1
# arxiv-id: 2101.11990v1
# published: 2021-01-28
# revised: 2021-01-28
# title: Aerosol generation in public restrooms
# journal: None
# authors: Jesse H. Schreck, Masoud Jahandar Lashaki, Javad Hashemi, Manhar Dhanak, Siddhartha Verma
# doi: 10.1063/5.0040310
# pdf_url: http://arxiv.org/pdf/2101.11990v1
# arxiv-id: 2101.07824v1
# published: 2021-01-19
# revised: 2021-01-19
# title: Machine learning applications for COVID-19: A state-of-the-art review
# journal: None
# authors: Firuz Kamalov, Aswani Cherukuri, Hana Sulieman, Fadi Thabtah, Akbar Hossain
# doi: None
# pdf_url: http://arxiv.org/pdf/2101.07824v1
# arxiv-id: 2101.04617v1
# published: 2021-01-12
# revised: 2021-01-12
# title: AI- and HPC-enabled Lead Generation for SARS-CoV-2: Models and Processes to Extract Druglike Molecules Contained in Natural Language Text
# journal: None
# ...
# doi: None
# pdf_url: http://arxiv.org/pdf/2005.11458v1
# arxiv-id: 2005.11254v1
# published: 2020-05-22
# revised: 2020-05-22
# title: Virtual Screening of Plant Metabolites against Main protease, RNA-dependent RNA polymerase and Spike protein of SARS-CoV-2: Therapeutics option of COVID-19
# journal: None
# authors: Md Sorwer Alam Parvez, Kazi Faizul Azim, Abdus Shukur Imran, Topu Raihan, Aklima Begum, Tasfia Saiyara Shammi, Sabbir Howlader, Farhana Rumzum Bhuiyan, Mahmudul Hasan
# doi: None
# pdf_url: http://arxiv.org/pdf/2005.11254v1
# arxiv-id: 2005.05625v2
# published: 2020-05-12
# revised: 2020-05-22
# title: How Reliable is Smartphone-based Electronic Contact Tracing for COVID-19?
# journal: Communications of the ACM 2022
# authors: Philipp H. Kindt, Trinad Chakraborty, Samarjit Chakraborty
# doi: 10.1145/3471933
# pdf_url: http://arxiv.org/pdf/2005.05625v2
# arxiv-id: 2005.10797v1
# published: 2020-05-21
# revised: 2020-05-21
# title: An Optimal Predictive Control Strategy for COVID-19 (SARS-CoV-2) Social Distancing Policies in Brazil
# journal: None
# authors: Marcelo Menezes Morato, Saulo Benchimol Bastos, Daniel Oliveira Cajueiro, Julio Elias Normey-Rico
# doi: None
# pdf_url: http://arxiv.org/pdf/2005.10797v1
# arxiv-id: 2005.10831v1
# published: 2020-05-21
# revised: 2020-05-21
# title: Repurpose Open Data to Discover Therapeutics for COVID-19 using Deep Learning
# journal: None
# authors: Xiangxiang Zeng, Xiang Song, Tengfei Ma, Xiaoqin Pan, Yadi Zhou, Yuan Hou, Zheng Zhang, George Karypis, Feixiong Cheng
# doi: None
# pdf_url: http://arxiv.org/pdf/2005.10831v1
# arxiv-id: 2005.10028v1
# published: 2020-05-20
# revised: 2020-05-20
# title: Repositioning of 8565 existing drugs for COVID-19
# journal: None
# authors: Kaifu Gao, Duc Duy Nguyen, Jiahui Chen, Rui Wang, Guo-Wei Wei
# doi: None
# pdf_url: http://arxiv.org/pdf/2005.10028v1
# arxiv-id: 2005.09805v1
# published: 2020-05-20
# revised: 2020-05-20
# title: Molecular Characterization of Ebselen Binding Activity to SARS-CoV-2 Main Protease
# journal: None
# authors: Cintia A. Menendez, Fabian Bylehn, Gustavo R. Perez-Lemus, Walter Alvarado, Juan J. de Pablo
# doi: None
# pdf_url: http://arxiv.org/pdf/2005.09805v1
# arxiv-id: 2005.12137v1
# published: 2020-05-19
# revised: 2020-05-19
# title: The challenges of deploying artificial intelligence models in a rapidly evolving pandemic
# journal: None
# authors: Yipeng Hu, Joseph Jacob, Geoffrey JM Parker, David J Hawkes, John R Hurst, Danail Stoyanov
# doi: 10.1038/s42256-020-0185-2
# pdf_url: http://arxiv.org/pdf/2005.12137v1
# arxiv-id: 2005.02666v2
# published: 2020-05-06
# revised: 2020-05-18
# title: Evolutionary Multi-Objective Design of SARS-CoV-2 Protease Inhibitor Candidates
# journal: LNCS 12270 (2020) 357-371
# authors: Tim Cofala, Lars Elend, Philip Mirbach, Jonas Prellberg, Thomas Teusch, Oliver Kramer
# doi: 10.1007/978-3-030-58115-2_25
# pdf_url: http://arxiv.org/pdf/2005.02666v2
# arxiv-id: 2005.08224v1
# published: 2020-05-17
# revised: 2020-05-17
# title: #Coronavirus or #Chinesevirus?!: Understanding the negative sentiment reflected in Tweets with racist hashtags across the development of COVID-19
# journal: None
# authors: Xin Pei, Deval Mehta
# doi: None
# pdf_url: http://arxiv.org/pdf/2005.08224v1
# arxiv-id: 2005.06380v2
# published: 2020-05-13
# revised: 2020-05-15
# title: Visualising COVID-19 Research
# journal: None
# authors: Pierre Le Bras, Azimeh Gharavi, David A. Robb, Ana F. Vidal, Stefano Padilla, Mike J. Chantler
# doi: None
# pdf_url: http://arxiv.org/pdf/2005.06380v2
# arxiv-id: 2005.05954v1
# published: 2020-05-12
# revised: 2020-05-12
# title: COVID-19Base: A knowledgebase to explore biomedical entities related to COVID-19
# journal: JMIR Med Inform 2020;8(11):e21648
# authors: Junaed Younus Khan, Md. Tawkat Islam Khondaker, Iram Tazim Hoque, Hamada Al-Absi, Mohammad Saifur Rahman, Tanvir Alam, M. Sohel Rahman
# doi: 10.2196/21648
# pdf_url: http://arxiv.org/pdf/2005.05954v1
# arxiv-id: 2005.07121v1
# published: 2020-05-11
# revised: 2020-05-11
# title: Using Bayesian Optimization to Accelerate Virtual Screening for the Discovery of Therapeutics Appropriate for Repurposing for COVID-19
# journal: None
# authors: Edward O. Pyzer-Knapp
# doi: None
# pdf_url: http://arxiv.org/pdf/2005.07121v1
# arxiv-id: 2005.03004v1
# published: 2020-05-05
# revised: 2020-05-05
# title: Adaptive Invariance for Molecule Property Prediction
# journal: None
# authors: Wengong Jin, Regina Barzilay, Tommi Jaakkola
# doi: None
# pdf_url: http://arxiv.org/pdf/2005.03004v1
# arxiv-id: 2005.02289v1
# published: 2020-05-05
# revised: 2020-05-05
# title: In Silico Trial to test COVID-19 candidate vaccines: a case study with UISS platform
# journal: None
# authors: Giulia Russo, Marzio Pennisi, Marco Viceconti, Francesco Pappalardo
# doi: None
# pdf_url: http://arxiv.org/pdf/2005.02289v1
# arxiv-id: 2005.02188v1
# published: 2020-05-05
# revised: 2020-05-05
# title: Mutations on COVID-19 diagnostic targets
# journal: None
# authors: Rui Wang, Yuta Hozumi, Changchuan Yin, Guo-Wei Wei
# doi: None
# pdf_url: http://arxiv.org/pdf/2005.02188v1
# arxiv-id: 2005.04108v1
# published: 2020-05-05
# revised: 2020-05-05
# title: Computational modeling of Human-nCoV protein-protein interaction network
# journal: None
# authors: Sovan Saha, Anup Kumar Halder, Soumyendu Sekhar Bandyopadhyay, Piyali Chatterjee, Mita Nasipuri, Subhadip Basu
# doi: None
# pdf_url: http://arxiv.org/pdf/2005.04108v1
# arxiv-id: 2004.07697v2
# published: 2020-04-16
# revised: 2020-05-04
# title: Computational Drug Repositioning and Elucidation of Mechanism of Action of Compounds against SARS-CoV-2
# journal: None
# authors: Francesco Napolitano, Gennaro Gambardella, Diego Carrella, Xin Gao, Diego di Bernardo
# doi: None
# pdf_url: http://arxiv.org/pdf/2004.07697v2
# arxiv-id: 2005.01042v1
# published: 2020-05-03
# revised: 2020-05-03
# title: Transcriptional landscape of SARS-CoV-2 infection dismantles pathogenic pathways activated by the virus, proposes unique sex-specific differences and predicts tailored therapeutic strategies
# journal: None
# authors: Paolo Fagone, Rosella Ciurleo, Salvo Danilo Lombardo, Carmelo Iacobello, Concetta Ilenia Palermo, Yehuda Shoenfeld, Klaus Bendtzen, Placido Bramanti, Ferdinando Nicoletti
# doi: None
# pdf_url: http://arxiv.org/pdf/2005.01042v1
# arxiv-id: 2003.14333v2
# published: 2020-03-30
# revised: 2020-05-03
# title: Prediction of repurposed drugs for treating lung injury in COVID-19
# journal: None
# authors: Bing He, Lana Garmire
# doi: None
# pdf_url: http://arxiv.org/pdf/2003.14333v2
# arxiv-id: 2005.00485v1
# published: 2020-04-30
# revised: 2020-04-30
# title: Getting Insights from a Large Corpus of Scientific Papers on Specialisted Comprehensive Topics -- the Case of COVID-19
# journal: None
# authors: Bernard Dousset, Josiane Mothe
# doi: None
# pdf_url: http://arxiv.org/pdf/2005.00485v1
# arxiv-id: 2004.14114v1
# published: 2020-04-29
# revised: 2020-04-29
# title: Decoding SARS-CoV-2 transmission, evolution and ramification on COVID-19 diagnosis, vaccine, and medicine
# journal: None
# authors: Rui Wang, Yuta Hozumi, Changchuan Yin, Guo-Wei Wei
# doi: None
# pdf_url: http://arxiv.org/pdf/2004.14114v1
# arxiv-id: 2004.13457v1
# published: 2020-04-28
# revised: 2020-04-28
# title: Lights and shadows of COVID-19, Technology and Industry 4.0
# journal: None
# authors: Nicola Melluso, Silvia Fareri, Gualtiero Fantoni, Andrea Bonaccorsi, Filippo Chiarello, Elena Coli, Vito Giordano, Pietro Manfredi, Shahin Manafi
# doi: None
# pdf_url: http://arxiv.org/pdf/2004.13457v1
# arxiv-id: 2004.12420v1
# published: 2020-04-26
# revised: 2020-04-26
# title: Exploring the SARS-CoV-2 virus-host-drug interactome for drug repurposing
# journal: Nat Commun 11, 3518 (2020)
# authors: Sepideh Sadegh, Julian Matschinske, David B. Blumenthal, Gihanna Galindez, Tim Kacprowski, Markus List, Reza Nasirigerdeh, Mhaned Oubounyt, Andreas Pichlmair, Tim Daniel Rose, Marisol Salgado-Albarrán, Julian Späth, Alexey Stukalov, Nina K. Wenke, Kevin Yuan, Josch K. Pauling, Jan Baumbach
# doi: 10.1038/s41467-020-17189-2
# pdf_url: http://arxiv.org/pdf/2004.12420v1
# arxiv-id: 2004.12055v1
# published: 2020-04-25
# revised: 2020-04-25
# title: In silico identification of clinically approved medicines against the main protease of SARS-CoV-2, causative agent of covid-19
# journal: None
# authors: Estari Mamidala, Rakesh Davella, Swapna Gurrapu, Pujala Shivakrishna
# doi: None
# pdf_url: http://arxiv.org/pdf/2004.12055v1
# arxiv-id: 2004.11695v1
# published: 2020-04-24
# revised: 2020-04-24
# title: Deep Sentiment Classification and Topic Discovery on Novel Coronavirus or COVID-19 Online Discussions: NLP Using LSTM Recurrent Neural Network Approach
# journal: None
# authors: Hamed Jelodar, Yongli Wang, Rita Orji, Hucheng Huang
# doi: None
# pdf_url: http://arxiv.org/pdf/2004.11695v1
# arxiv-id: 2004.10878v1
# published: 2020-04-22
# revised: 2020-04-22
# title: Visible Insights of the Invisible Pandemic: A Scientometric, Altmetric and Topic Trend Analysis
# journal: None
# authors: Sujit Bhattacharya, Shubham Singh
# doi: None
# pdf_url: http://arxiv.org/pdf/2004.10878v1
# arxiv-id: 2004.10641v1
# published: 2020-04-22
# revised: 2020-04-22
# title: Automatic Detection of Coronavirus Disease (COVID-19) in X-ray and CT Images: A Machine Learning-Based Approach
# journal: None
# authors: Sara Hosseinzadeh Kassani, Peyman Hosseinzadeh Kassasni, Michal J. Wesolowski, Kevin A. Schneider, Ralph Deters
# doi: None
# pdf_url: http://arxiv.org/pdf/2004.10641v1
# arxiv-id: 2004.08920v1
# published: 2020-04-19
# revised: 2020-04-19
# title: Hispidin and Lepidine E: two Natural Compounds and Folic acid as Potential Inhibitors of 2019-novel coronavirus Main Protease (2019-nCoVMpro), molecular docking and SAR study
# journal: None
# authors: Talia Serseg, Khedidja Benarous, Mohamed Yousfi
# doi: None
# pdf_url: http://arxiv.org/pdf/2004.08920v1
# arxiv-id: 2004.08557v1
# published: 2020-04-18
# revised: 2020-04-18
# title: Monitoring the spread of COVID-19 by estimating reproduction numbers over time
# journal: None
# authors: Thomas Hotz, Matthias Glock, Stefan Heyder, Sebastian Semper, Anne Böhle, Alexander Krämer
# doi: None
# pdf_url: http://arxiv.org/pdf/2004.08557v1
# arxiv-id: 2004.08491v1
# published: 2020-04-18
# revised: 2020-04-18
# title: Is the anti-filarial drug diethylcarbamazine useful to treat COVID-19?
# journal: None
# authors: Anuruddha Abeygunasekera, Saroj Jayasinghe
# doi: None
# pdf_url: http://arxiv.org/pdf/2004.08491v1
# arxiv-id: 2004.00217v2
# published: 2020-04-01
# revised: 2020-04-17
# title: Molecular docking studies on Jensenone from eucalyptus essential oil as a potential inhibitor of COVID 19 corona virus infection
# journal: None
# authors: Arun Dev Sharma, Inderjeet Kaur
# doi: None
# pdf_url: http://arxiv.org/pdf/2004.00217v2
# arxiv-id: 2004.07750v1
# published: 2020-04-16
# revised: 2020-04-16
# title: Extracting the effective contact rate of COVID-19 pandemic
# journal: None
# authors: Gaurav Goswami, Jayanti Prasad, Mansi Dhuria
# doi: None
# pdf_url: http://arxiv.org/pdf/2004.07750v1
# arxiv-id: 2003.10642v2
# published: 2020-03-24
# revised: 2020-04-15
# title: In Silico Investigations on the Potential Inhibitors for COVID-19 Protease
# journal: None
# authors: Ambrish Kumar Srivastava, Abhishek Kumar, Gargi Tiwari, Ratnesh Kumar, Neeraj Misra
# doi: None
# pdf_url: http://arxiv.org/pdf/2003.10642v2
# arxiv-id: 2004.07086v1
# published: 2020-04-15
# revised: 2020-04-15
# title: Prediction of potential inhibitors for RNA-dependent RNA polymerase of SARS-CoV-2 using comprehensive drug repurposing and molecular docking approach
# journal: International Journal of Biological Macromolecules 163 (2020)
#   1787-1797
# authors: Md. Sorwer Alam Parvez, Md. Adnan Karim, Mahmudul Hasan, Jomana Jaman, Ziaul Karim, Tohura Tahsin, Md. Nazmul Hasan, Mohammad Jakir Hosen
# doi: 10.1016/j.ijbiomac.2020.09.098
# pdf_url: http://arxiv.org/pdf/2004.07086v1
# arxiv-id: 2004.06447v1
# published: 2020-04-14
# revised: 2020-04-14
# title: Molecular docking and binding mode analysis of selected FDA approved drugs against COVID-19 selected key protein targets: An effort towards drug repurposing to identify the combination therapy to combat COVID-19
# journal: None
# authors: Atanu Barik, Geeta Rai, Gyan Modi
# doi: None
# pdf_url: http://arxiv.org/pdf/2004.06447v1
# arxiv-id: 2004.05684v1
# published: 2020-04-12
# revised: 2020-04-12
# title: A kinetic model for qualitative understanding and analysis of the effect of complete lockdown imposed by India for controlling the COVID-19 disease spread by the SARS-CoV-2 virus
# journal: None
# authors: Raj Kishore, Prashant Kumar Jha, Shreeja Das, Dheeresh Agarwal, Tanmay Maloo, Hansraj Pegu, Devadatta Sahoo, Ankita Singhal, Kisor K. Sahu
# doi: None
# pdf_url: http://arxiv.org/pdf/2004.05684v1
# arxiv-id: 2004.02136v3
# published: 2020-04-05
# revised: 2020-04-11
# title: One-shot screening of potential peptide ligands on HR1 domain in COVID-19 glycosylated spike (S) protein with deep siamese network
# journal: None
# authors: Nicolò Savioli
# doi: None
# pdf_url: http://arxiv.org/pdf/2004.02136v3
# arxiv-id: 2004.04874v1
# published: 2020-04-10
# revised: 2020-04-10
# title: Implications of the virus-encoded miRNA and host miRNA in the pathogenicity of SARS-CoV-2
# journal: None
# authors: Zhi Liu, Jianwei Wang, Yuyu Xu, Mengchen Guo, Kai Mi, Rui Xu, Yang Pei, Qiangkun Zhang, Xiaoting Luan, Zhibin Hu, Xingyin Liu#
# doi: None
# pdf_url: http://arxiv.org/pdf/2004.04874v1
# arxiv-id: 2004.03766v1
# published: 2020-04-08
# revised: 2020-04-08
# title: Screening of Therapeutic Agents for COVID-19 using Machine Learning and Ensemble Docking Simulations
# journal: None
# authors: Rohit Batra, Henry Chan, Ganesh Kamath, Rampi Ramprasad, Mathew J. Cherukara, Subramanian Sankaranarayanan
# doi: None
# pdf_url: http://arxiv.org/pdf/2004.03766v1
# arxiv-id: 2004.02085v1
# published: 2020-04-05
# revised: 2020-04-05
# title: Information Mining for COVID-19 Research From a Large Volume of Scientific Literature
# journal: None
# authors: Sabber Ahamed, Manar Samad
# doi: None
# pdf_url: http://arxiv.org/pdf/2004.02085v1
# arxiv-id: 2003.13670v4
# published: 2020-03-30
# revised: 2020-04-03
# title: Anonymous Collocation Discovery: Harnessing Privacy to Tame the Coronavirus
# journal: None
# authors: Ran Canetti, Ari Trachtenberg, Mayank Varia
# doi: None
# pdf_url: http://arxiv.org/pdf/2003.13670v4
# arxiv-id: 2004.01634v1
# published: 2020-04-03
# revised: 2020-04-03
# title: In Silico Screening of Some Naturally Occurring Bioactive Compounds Predicts Potential Inhibitors against SARS-COV-2 (COVID-19) Protease
# journal: None
# authors: Ashok Kumar Mishra, Satya Prakash Tewari
# doi: None
# pdf_url: http://arxiv.org/pdf/2004.01634v1
# arxiv-id: 2004.00746v1
# published: 2020-04-02
# revised: 2020-04-02
# title: Coronavirus SARS-CoV-2: Analysis of subgenomic mRNA transcription, 3CLpro and PL2pro protease cleavage sites and protein synthesis
# journal: None
# authors: Miguel Ramos Pascual
# doi: None
# pdf_url: http://arxiv.org/pdf/2004.00746v1
# arxiv-id: 2003.13665v1
# published: 2020-03-30
# revised: 2020-03-30
# title: Genomics-guided molecular maps of coronavirus targets in human cells: a path toward the repurposing of existing drugs to mitigate the pandemic
# journal: None
# authors: Gennadi Glinsky
# doi: None
# pdf_url: http://arxiv.org/pdf/2003.13665v1
# arxiv-id: 2003.14258v1
# published: 2020-03-30
# revised: 2020-03-30
# title: Nanomechanical sonification of the 2019-nCoV coronavirus spike protein through a materiomusical approach
# journal: None
# authors: Markus J. Buehler
# doi: None
# pdf_url: http://arxiv.org/pdf/2003.14258v1
# arxiv-id: 2003.12454v1
# published: 2020-03-26
# revised: 2020-03-26
# title: A Machine Learning alternative to placebo-controlled clinical trials upon new diseases: A primer
# journal: None
# authors: Ezequiel Alvarez, Federico Lamagna, Manuel Szewc
# doi: None
# pdf_url: http://arxiv.org/pdf/2003.12454v1
# arxiv-id: 2003.04524v1
# published: 2020-03-10
# revised: 2020-03-10
# title: Old Drugs for Newly Emerging Viral Disease, COVID-19: Bioinformatic Prospective
# journal: None
# authors: Mohammad Reza Dayer
# doi: None
# pdf_url: http://arxiv.org/pdf/2003.04524v1
# arxiv-id: 2003.00751v1
# published: 2020-03-02
# revised: 2020-03-02
# title: Regulation of interferon production as a potential strategy for COVID-19 treatment
# journal: None
# authors: Xiaobing Deng, Xiaoyu Yu, Jianfeng Pei
# doi: None
# pdf_url: http://arxiv.org/pdf/2003.00751v1

# %%
len(article_results)
# Out:
# 304

# %%
article_results
# Out:
#          arxiv-id   published     revised  \
# 0    2109.06377v4  2021-09-14  2022-12-22
# 1    2212.09867v1  2022-12-19  2022-12-19
# 2    2212.09610v1  2022-12-19  2022-12-19
# 3    2212.00023v2  2022-11-30  2022-12-08
# 4    2212.03911v1  2022-12-07  2022-12-07
# ..            ...         ...         ...
# 299  2003.13665v1  2020-03-30  2020-03-30
# 300  2003.14258v1  2020-03-30  2020-03-30
# 301  2003.12454v1  2020-03-26  2020-03-26
# 302  2003.04524v1  2020-03-10  2020-03-10
# 303  2003.00751v1  2020-03-02  2020-03-02
#
#                                                  title journal  \
# 0    ASGARD: A Single-cell Guided pipeline to Aid R...    None
# 1    Detecting Contradictory COVID-19 Drug Efficacy...    None
# 2    Drying of Bio-colloidal Sessile Droplets: Adva...    None
# 3    Random Copolymer inverse design system orienti...    None
# 4    Analysis of Drug repurposing Knowledge graphs ...    None
# ..                                                 ...     ...
# 299  Genomics-guided molecular maps of coronavirus ...    None
# 300  Nanomechanical sonification of the 2019-nCoV c...    None
# 301  A Machine Learning alternative to placebo-cont...    None
# 302  Old Drugs for Newly Emerging Viral Disease, CO...    None
# 303  Regulation of interferon production as a poten...    None
#
#                                                authors   doi  \
# 0    Bing He, Yao Xiao, Haodong Liang, Qianhui Huan...  None
# 1    Daniel N. Sosa, Malavika Suresh, Christopher P...  None
# 2           Anusuya Pal, Amalesh Gope, Anupam Sengupta  None
# 3                                 Tianyu Wu, Yang Tang  None
# 4                                  Ajay Kumar Gogineni  None
# ..                                                 ...   ...
# 299                                    Gennadi Glinsky  None
# 300                                  Markus J. Buehler  None
# 301   Ezequiel Alvarez, Federico Lamagna, Manuel Szewc  None
# 302                                Mohammad Reza Dayer  None
# 303             Xiaobing Deng, Xiaoyu Yu, Jianfeng Pei  None
#
#                                pdf_url
# 0    http://arxiv.org/pdf/2109.06377v4
# 1    http://arxiv.org/pdf/2212.09867v1
# 2    http://arxiv.org/pdf/2212.09610v1
# 3    http://arxiv.org/pdf/2212.00023v2
# 4    http://arxiv.org/pdf/2212.03911v1
# ..                                 ...
# 299  http://arxiv.org/pdf/2003.13665v1
# 300  http://arxiv.org/pdf/2003.14258v1
# 301  http://arxiv.org/pdf/2003.12454v1
# 302  http://arxiv.org/pdf/2003.04524v1
# 303  http://arxiv.org/pdf/2003.00751v1
#
# [304 rows x 8 columns]

# %%
article_results_for_dl = article_results.copy()

# %% [markdown]
# The pdf_url column in the API output contains URLs from the arxiv.org domain. This must be replaced with the export.arxiv.org subdomain before programmatically downloading the PDF full text to avoid being blocked by the firewall.

# %%
article_results_for_dl = article_results_for_dl.replace('http://', 'http://export.', regex=True)
article_results_for_dl
# Out:
#          arxiv-id   published     revised  \
# 0    2109.06377v4  2021-09-14  2022-12-22
# 1    2212.09867v1  2022-12-19  2022-12-19
# 2    2212.09610v1  2022-12-19  2022-12-19
# 3    2212.00023v2  2022-11-30  2022-12-08
# 4    2212.03911v1  2022-12-07  2022-12-07
# ..            ...         ...         ...
# 299  2003.13665v1  2020-03-30  2020-03-30
# 300  2003.14258v1  2020-03-30  2020-03-30
# 301  2003.12454v1  2020-03-26  2020-03-26
# 302  2003.04524v1  2020-03-10  2020-03-10
# 303  2003.00751v1  2020-03-02  2020-03-02
#
#                                                  title journal  \
# 0    ASGARD: A Single-cell Guided pipeline to Aid R...    None
# 1    Detecting Contradictory COVID-19 Drug Efficacy...    None
# 2    Drying of Bio-colloidal Sessile Droplets: Adva...    None
# 3    Random Copolymer inverse design system orienti...    None
# 4    Analysis of Drug repurposing Knowledge graphs ...    None
# ..                                                 ...     ...
# 299  Genomics-guided molecular maps of coronavirus ...    None
# 300  Nanomechanical sonification of the 2019-nCoV c...    None
# 301  A Machine Learning alternative to placebo-cont...    None
# 302  Old Drugs for Newly Emerging Viral Disease, CO...    None
# 303  Regulation of interferon production as a poten...    None
#
#                                                authors   doi  \
# 0    Bing He, Yao Xiao, Haodong Liang, Qianhui Huan...  None
# 1    Daniel N. Sosa, Malavika Suresh, Christopher P...  None
# 2           Anusuya Pal, Amalesh Gope, Anupam Sengupta  None
# 3                                 Tianyu Wu, Yang Tang  None
# 4                                  Ajay Kumar Gogineni  None
# ..                                                 ...   ...
# 299                                    Gennadi Glinsky  None
# 300                                  Markus J. Buehler  None
# 301   Ezequiel Alvarez, Federico Lamagna, Manuel Szewc  None
# 302                                Mohammad Reza Dayer  None
# 303             Xiaobing Deng, Xiaoyu Yu, Jianfeng Pei  None
#
#                                       pdf_url
# 0    http://export.arxiv.org/pdf/2109.06377v4
# 1    http://export.arxiv.org/pdf/2212.09867v1
# 2    http://export.arxiv.org/pdf/2212.09610v1
# 3    http://export.arxiv.org/pdf/2212.00023v2
# 4    http://export.arxiv.org/pdf/2212.03911v1
# ..                                        ...
# 299  http://export.arxiv.org/pdf/2003.13665v1
# 300  http://export.arxiv.org/pdf/2003.14258v1
# 301  http://export.arxiv.org/pdf/2003.12454v1
# 302  http://export.arxiv.org/pdf/2003.04524v1
# 303  http://export.arxiv.org/pdf/2003.00751v1
#
# [304 rows x 8 columns]

# %%
with open('2023-01-06_arxiv_results_for_dl.pickle', "wb") as f:
    pickle.dump(article_results_for_dl, f)

# %% [markdown]
# ## 5. Check for missing values
#
# Concise summary of DataFrame to see if there are any columns with missing values.

# %%
article_results_for_dl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   arxiv-id   304 non-null    object
#  1   published  304 non-null    object
#  2   revised    304 non-null    object
#  3   title      304 non-null    object
#  4   journal    39 non-null     object
#  5   authors    304 non-null    object
#  6   doi        63 non-null     object
#  7   pdf_url    304 non-null    object
# dtypes: object(8)
# memory usage: 19.1+ KB

# %% [markdown]
# We can see that most of the articles have a missing journal reference and DOI. In most cases submissions are not yet published so this information will be added by the author at a later date.

# %% [markdown]
# ### References
#
# * arXiv free distribution service and open-access archive https://arxiv.org/
#
# * arXiv API Access https://info.arxiv.org/help/api/index.html
#
# * arXiv API User's Manual https://arxiv.org/help/api/user-manual
#
# * Python wrapper for arXiv API https://github.com/lukasschwab/arxiv.py
